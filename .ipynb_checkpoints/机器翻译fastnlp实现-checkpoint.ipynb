# %%
import fastNLP
import pandas as pd

from fastNLP.embeddings import BertEmbedding
from fastNLP.models import BertForQuestionAnswering
from fastNLP.core.losses import CMRC2018Loss
from fastNLP.core.metrics import CMRC2018Metric
from fastNLP.io.pipe.qa import CMRC2018BertPipe
from fastNLP import Trainer, BucketSampler
from fastNLP import WarmupCallback, GradientClipCallback
from fastNLP.core.optimizer import AdamW
from fastNLP import DataSet,Instance
from fastNLP.io import DataBundle
from copy import deepcopy
from fastNLP import DataSet, Instance

import numpy as np
# import pickle
import operator
# import pandas as pd
import jieba
# from language.langconv import *
import os

# %%
# qa_data=pd.read_csv('./data/qa/qa.csv')
translation_data=pd.read_csv('./data/translation/translation.csv')

# %%
# 由于是从那个问答系统的数据集改的

# %% [markdown]
# 所以title，content保持和answers的值相同，answers_start我也设定成从0开始，这样应该就可以解决问题了，但是需要网上跑着试一试

# %%
translation_data.head()
# Out:
#    Unnamed: 0 input_texts target_texts
# 0           0         Go.        Πάμε.
# 1           1        Run!       Τρέξε!
# 2           2        Run!      Τρέξτε!
# 3           3        Who?       Ποιος;
# 4           4        Wow!       Ουάου!

# %%
translation_data.shape
# Out:
# (10000, 3)

# %%
def get_DataBuddle(qa_data):
    question_texts=[str(j) for j in qa_data.input_texts]

    pre_answer_texts=[str(j) for j in qa_data.target_texts]

    answer_texts=[]

    for i in range(len(question_texts)):
        answer_texts.append([pre_answer_texts[i],pre_answer_texts[i],pre_answer_texts[i]])

    id_texts=[]
    for i in range(len(question_texts)):
        id_texts.append('DEV_0_QUERY_'+str(i))

    context_texts=pre_answer_texts
    title_texts=pre_answer_texts

    answer_starts_texts=[]
    for i in range(len(question_texts)):
        a=list()
        a.append(0)
        a.append(0)
        a.append(0)
        answer_starts_texts.append(a)
    ds = DataSet()

    for i in range(len(question_texts)):
        title=title_texts[i]
        context=context_texts[i]
        question=question_texts[i]
        answers=answer_texts[i]
        answer_starts=answer_starts_texts
        id=id_texts
        ds.append(Instance(title=title, context=context, question=question, answers=answers,
                                           answer_starts=answer_starts,id=id))
    return ds

# %%
ds=get_DataBuddle(translation_data)

# %%
data_bundle=DataBundle()
train_data, dev_data = ds.split(0.2, shuffle=False)
data_bundle.set_dataset(train_data, 'train')
data_bundle.set_dataset(dev_data, 'dev')
# Out:
# In total 2 datasets:
# 	train has 8000 instances.
# 	dev has 2000 instances.

# %% [markdown]
# # 预处理

# %% [markdown]
# 获取分词器，对于不同语种就换一种分词器就行，这个以待研究

# %%
max_len=510

# %%
tokenize_method='spacy'
# tokenize_method='spacy'
lang='en_core_web_sm'
def _raw_split(sent):
    return sent.split()
def _cn_char_split(sent):
    return [chars for chars in sent]
r"""

:param str tokenize_method: 获取tokenzier方法
:param str lang: 语言，当前仅支持en
:return: 返回tokenize函数
"""
tokenizer_dict = {
    'spacy': None,
    'raw': _raw_split,
    'cn-char': _cn_char_split,
}
if tokenize_method == 'spacy':
    import spacy
    spacy.prefer_gpu()
    if lang != 'en_core_web_sm':
        raise RuntimeError("Spacy only supports en right right.")
    # 估计目前是不支持spacy用法，所以才有这么回事
    #到时候想法子改一下参数就行了
    en = spacy.load(lang)
    tokenizer = lambda x: [w.text for w in en.tokenizer(x)]
elif tokenize_method in tokenizer_dict:
    tokenizer = tokenizer_dict[tokenize_method]
else:
    raise RuntimeError(f"Only support {tokenizer_dict.keys()} tokenizer.")

# %%
def _concat_clip(data_bundle, max_len, concat_field_name='raw_chars'):
    r"""
    处理data_bundle中的DataSet，将context与question按照character进行tokenize，然后使用[SEP]将两者连接起来。

    会新增field: context_len(int), raw_words(list[str]), target_start(int), target_end(int)其中target_start
    与target_end是与raw_chars等长的。其中target_start和target_end是前闭后闭的区间。

    :param DataBundle data_bundle: 类似["a", "b", "[SEP]", "c", ]
    :return:
    """
#     tokenizer = get_tokenizer('cn-char', lang='cn')
    for name in list(data_bundle.datasets.keys()):
        ds = data_bundle.get_dataset(name)
        data_bundle.delete_dataset(name)
        new_ds = DataSet()
        # i=0
        for ins in ds:
        #     i=i+1
            new_ins = deepcopy(ins)
            context = ins['context']
            question = ins['question']
        #     print(context)
        #     print(question)
            cnt_lst = tokenizer(context)
        #     print(cnt_lst)
            q_lst = tokenizer(question)
        #     print(q_lst)
            answer_start = -1
        #     print('=='*20)
            print(len(cnt_lst))
            print(len(q_lst))
            print(len(cnt_lst) + len(q_lst) + 3)
            if len(cnt_lst) + len(q_lst) + 3 > max_len:  
                # 预留开头的[CLS]和[SEP]和中间的[sep]
                if 'answer_starts' in ins and 'answers' in ins:
                    answer_start = int(ins['answer_starts'][0][0])
                    print('answer_start',answer_start)
                    answer = ins['answers'][0]
                    answer_end = answer_start + len(answer)
                    if answer_end > max_len - 3 - len(q_lst):
                        span_start = answer_end + 3 + len(q_lst) - max_len
                        span_end = answer_end
                    else:
                        span_start = 0
                        span_end = max_len - 3 - len(q_lst)
                    cnt_lst = cnt_lst[span_start:span_end]
                    answer_start = int(ins['answer_starts'][0][0])
                    answer_start -= span_start
                    answer_end = answer_start + len(ins['answers'][0])
                else:
                    cnt_lst = cnt_lst[:max_len - len(q_lst) - 3]
            else:
                if 'answer_starts' in ins and 'answers' in ins:
                    print('='*20)
                    print(ins['answer_starts'][0])
                    answer_start = int(ins['answer_starts'][0][0])
                    print('<'*20)
                    print(answer_start)
                    answer_end = answer_start + len(ins['answers'][0])
                    print(ins['answers'])
                    print(answer_end)
            tokens = cnt_lst + ['[SEP]'] + q_lst
            new_ins['context_len'] = len(cnt_lst)
            new_ins['raw_chars'] = tokens
            if answer_start != -1:
                    new_ins['target_start'] = answer_start
        #             print(answer_start)
                    new_ins['target_end'] = answer_end - 1
        #             print(answer_end-1)
            new_ds.append(new_ins)
            data_bundle.set_dataset(new_ds, name)

    return data_bundle

# %%
data_bundle = _concat_clip(data_bundle
                                   , max_len=max_len
                                   , concat_field_name='raw_chars')
# Out:
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Χρειάζεται χρήματα.', 'Χρειάζεται χρήματα.', 'Χρειάζεται χρήματα.']
# 19
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Με σέβεται.', 'Με σέβεται.', 'Με σέβεται.']
# 11
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Φαίνεται χαρούμενος.', 'Φαίνεται χαρούμενος.', 'Φαίνεται χαρούμενος.']
# 20
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Φαίνεται ευτυχισμένος.', 'Φαίνεται ευτυχισμένος.', 'Φαίνεται ευτυχισμένος.']
# 22
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δείχνει κουρασμένος.', 'Δείχνει κουρασμένος.', 'Δείχνει κουρασμένος.']
# 20
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Φαίνεται κουρασμένος.', 'Φαίνεται κουρασμένος.', 'Φαίνεται κουρασμένος.']
# 21
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σε εμπιστεύτηκε.', 'Σε εμπιστεύτηκε.', 'Σε εμπιστεύτηκε.']
# 16
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Σ' εμπιστεύτηκε.", "Σ' εμπιστεύτηκε.", "Σ' εμπιστεύτηκε."]
# 16
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σας εμπιστεύτηκε.', 'Σας εμπιστεύτηκε.', 'Σας εμπιστεύτηκε.']
# 17
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ήταν Εγγλέζος.', 'Ήταν Εγγλέζος.', 'Ήταν Εγγλέζος.']
# 14
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ήταν Άγγλος.', 'Ήταν Άγγλος.', 'Ήταν Άγγλος.']
# 12
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ήταν υπομονετικός.', 'Ήταν υπομονετικός.', 'Ήταν υπομονετικός.']
# 18
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δε θα πάει.', 'Δε θα πάει.', 'Δε θα πάει.']
# 11
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Πώς ήταν η Βοστώνη;', 'Πώς ήταν η Βοστώνη;', 'Πώς ήταν η Βοστώνη;']
# 19
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Πώς είναι η σύζυγος;', 'Πώς είναι η σύζυγος;', 'Πώς είναι η σύζυγος;']
# 20
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είμαι στο Λονδίνο.', 'Είμαι στο Λονδίνο.', 'Είμαι στο Λονδίνο.']
# 18
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Έφαγα το κρέας.', 'Έφαγα το κρέας.', 'Έφαγα το κρέας.']
# 15
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σε πίστεψα.', 'Σε πίστεψα.', 'Σε πίστεψα.']
# 11
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σας πίστεψα.', 'Σας πίστεψα.', 'Σας πίστεψα.']
# 12
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σε πρόδωσα.', 'Σε πρόδωσα.', 'Σε πρόδωσα.']
# 11
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σας πρόδωσα.', 'Σας πρόδωσα.', 'Σας πρόδωσα.']
# 12
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Έσπασα το πόδι μου.', 'Έσπασα το πόδι μου.', 'Έσπασα το πόδι μου.']
# 19
# 3
# 5
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δε γέλασα.', 'Δε γέλασα.', 'Δε γέλασα.']
# 10
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Πίνω καφέ.', 'Πίνω καφέ.', 'Πίνω καφέ.']
# 10
# 3
# 5
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σε συμπονώ.', 'Σε συμπονώ.', 'Σε συμπονώ.']
# 11
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Τον ακολούθησα.', 'Τον ακολούθησα.', 'Τον ακολούθησα.']
# 15
# 3
# 5
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σηκώθηκα νωρίς.', 'Σηκώθηκα νωρίς.', 'Σηκώθηκα νωρίς.']
# 15
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μισώ τις Δευτέρες.', 'Μισώ τις Δευτέρες.', 'Μισώ τις Δευτέρες.']
# 18
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μισώ το σιδέρωμα.', 'Μισώ το σιδέρωμα.', 'Μισώ το σιδέρωμα.']
# 17
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μισώ το καραόκε.', 'Μισώ το καραόκε.', 'Μισώ το καραόκε.']
# 16
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μισώ τους γρίφους.', 'Μισώ τους γρίφους.', 'Μισώ τους γρίφους.']
# 18
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μισώ το σπανάκι.', 'Μισώ το σπανάκι.', 'Μισώ το σπανάκι.']
# 16
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Έχω ένα όνειρο.', 'Έχω ένα όνειρο.', 'Έχω ένα όνειρο.']
# 15
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Έχω μια ιδέα.', 'Έχω μια ιδέα.', 'Έχω μια ιδέα.']
# 13
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Έχω αλλάξει.', 'Έχω αλλάξει.', 'Έχω αλλάξει.']
# 12
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν έχω παιδιά.', 'Δεν έχω παιδιά.', 'Δεν έχω παιδιά.']
# 15
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν έχω χρόνο.', 'Δεν έχω χρόνο.', 'Δεν έχω χρόνο.']
# 14
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Έχω ένα παιδί.', 'Έχω ένα παιδί.', 'Έχω ένα παιδί.']
# 14
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μου αρέσουν τα κάστρα.', 'Μου αρέσουν τα κάστρα.', 'Μου αρέσουν τα κάστρα.']
# 22
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Μ' αρέσουν τα κάστρα.", "Μ' αρέσουν τα κάστρα.", "Μ' αρέσουν τα κάστρα."]
# 21
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μου αρέσει το κοτόπουλο.', 'Μου αρέσει το κοτόπουλο.', 'Μου αρέσει το κοτόπουλο.']
# 24
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μου αρέσουν τα μπισκότα.', 'Μου αρέσουν τα μπισκότα.', 'Μου αρέσουν τα μπισκότα.']
# 24
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μου αρέσουν τα λουλούδια.', 'Μου αρέσουν τα λουλούδια.', 'Μου αρέσουν τα λουλούδια.']
# 25
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Μ' αρέσουν τα λουλούδια.", "Μ' αρέσουν τα λουλούδια.", "Μ' αρέσουν τα λουλούδια."]
# 24
# 6
# 5
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μου αρέσει η ζωή μου.', 'Μου αρέσει η ζωή μου.', 'Μου αρέσει η ζωή μου.']
# 21
# 7
# 5
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Μ' αρέσει η ζωή μου.", "Μ' αρέσει η ζωή μου.", "Μ' αρέσει η ζωή μου."]
# 20
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μου αρέσει να διαβάζω.', 'Μου αρέσει να διαβάζω.', 'Μου αρέσει να διαβάζω.']
# 22
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Μ' αρέσει να διαβάζω.", "Μ' αρέσει να διαβάζω.", "Μ' αρέσει να διαβάζω."]
# 21
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Μ' αρέσει να τραγουδώ.", "Μ' αρέσει να τραγουδώ.", "Μ' αρέσει να τραγουδώ."]
# 22
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μου αρέσει να τραγουδάω.', 'Μου αρέσει να τραγουδάω.', 'Μου αρέσει να τραγουδάω.']
# 24
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μου αρέσει να διαβάζω.', 'Μου αρέσει να διαβάζω.', 'Μου αρέσει να διαβάζω.']
# 22
# 6
# 5
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Μ' αρέσει να διαβάζω.", "Μ' αρέσει να διαβάζω.", "Μ' αρέσει να διαβάζω."]
# 21
# 6
# 5
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Μ' αρέσει να τραγουδώ.", "Μ' αρέσει να τραγουδώ.", "Μ' αρέσει να τραγουδώ."]
# 22
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μου αρέσει να τραγουδάω.', 'Μου αρέσει να τραγουδάω.', 'Μου αρέσει να τραγουδάω.']
# 24
# 6
# 5
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Μ' αρέσει να κολυμπάω.", "Μ' αρέσει να κολυμπάω.", "Μ' αρέσει να κολυμπάω."]
# 22
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μου αρέσει να κολυμπώ.', 'Μου αρέσει να κολυμπώ.', 'Μου αρέσει να κολυμπώ.']
# 22
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Μ' αρέσουν οι χελώνες.", "Μ' αρέσουν οι χελώνες.", "Μ' αρέσουν οι χελώνες."]
# 22
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μου αρέσουν οι χελώνες.', 'Μου αρέσουν οι χελώνες.', 'Μου αρέσουν οι χελώνες.']
# 23
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Λατρεύω τα καρότα.', 'Λατρεύω τα καρότα.', 'Λατρεύω τα καρότα.']
# 18
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Αγαπάω τα λουλούδια.', 'Αγαπάω τα λουλούδια.', 'Αγαπάω τα λουλούδια.']
# 20
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Λατρεύω τη ζωή μου.', 'Λατρεύω τη ζωή μου.', 'Λατρεύω τη ζωή μου.']
# 19
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Αγαπάω τη δουλειά μου.', 'Αγαπάω τη δουλειά μου.', 'Αγαπάω τη δουλειά μου.']
# 22
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Αγαπώ τη δουλειά μου.', 'Αγαπώ τη δουλειά μου.', 'Αγαπώ τη δουλειά μου.']
# 21
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Λατρεύω τον ήλιο.', 'Λατρεύω τον ήλιο.', 'Λατρεύω τον ήλιο.']
# 17
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Πρέπει να αγοράσω ένα.', 'Πρέπει να αγοράσω ένα.', 'Πρέπει να αγοράσω ένα.']
# 22
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Χρειάζομαι φίλους.', 'Χρειάζομαι φίλους.', 'Χρειάζομαι φίλους.']
# 18
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Χρειάζομαι φίλες.', 'Χρειάζομαι φίλες.', 'Χρειάζομαι φίλες.']
# 17
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Χρειάζομαι τα κλειδιά μου.', 'Χρειάζομαι τα κλειδιά μου.', 'Χρειάζομαι τα κλειδιά μου.']
# 26
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν πλήρωσα τίποτα.', 'Δεν πλήρωσα τίποτα.', 'Δεν πλήρωσα τίποτα.']
# 19
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν είπα τίποτα.', 'Δεν είπα τίποτα.', 'Δεν είπα τίποτα.']
# 16
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είδα πέντε άντρες.', 'Είδα πέντε άντρες.', 'Είδα πέντε άντρες.']
# 18
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Πουλάω λουλούδια.', 'Πουλάω λουλούδια.', 'Πουλάω λουλούδια.']
# 17
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μιλάω Γαλλικά.', 'Μιλάω Γαλλικά.', 'Μιλάω Γαλλικά.']
# 14
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Διδάσκω Γαλλικά.', 'Διδάσκω Γαλλικά.', 'Διδάσκω Γαλλικά.']
# 16
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Νομίζω ότι μπορούμε.', 'Νομίζω ότι μπορούμε.', 'Νομίζω ότι μπορούμε.']
# 20
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Έστριψα δεξιά.', 'Έστριψα δεξιά.', 'Έστριψα δεξιά.']
# 14
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Συνήθως περπατάω.', 'Συνήθως περπατάω.', 'Συνήθως περπατάω.']
# 17
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θέλω ένα ποτό.', 'Θέλω ένα ποτό.', 'Θέλω ένα ποτό.']
# 14
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θέλω λεπτομέρειες.', 'Θέλω λεπτομέρειες.', 'Θέλω λεπτομέρειες.']
# 18
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θέλω εκδίκηση.', 'Θέλω εκδίκηση.', 'Θέλω εκδίκηση.']
# 14
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θέλω να βοηθήσω.', 'Θέλω να βοηθήσω.', 'Θέλω να βοηθήσω.']
# 16
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ήμουν όλος αυτιά.', 'Ήμουν όλος αυτιά.', 'Ήμουν όλος αυτιά.']
# 17
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ήμουν όλη αυτιά.', 'Ήμουν όλη αυτιά.', 'Ήμουν όλη αυτιά.']
# 16
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ήμουν ξυπόλυτος.', 'Ήμουν ξυπόλυτος.', 'Ήμουν ξυπόλυτος.']
# 16
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ήμουν ξυπόλυτη.', 'Ήμουν ξυπόλυτη.', 'Ήμουν ξυπόλυτη.']
# 15
# 2
# 4
# 9
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Κοιμόμουν.', 'Κοιμόμουν.', 'Κοιμόμουν.']
# 10
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν ήμουν μόνος.', 'Δεν ήμουν μόνος.', 'Δεν ήμουν μόνος.']
# 16
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν ήμουν μόνη.', 'Δεν ήμουν μόνη.', 'Δεν ήμουν μόνη.']
# 15
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν ήμουν θυμωμένος.', 'Δεν ήμουν θυμωμένος.', 'Δεν ήμουν θυμωμένος.']
# 20
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν ήμουν θυμωμένη.', 'Δεν ήμουν θυμωμένη.', 'Δεν ήμουν θυμωμένη.']
# 19
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν ήμουν πιωμένος.', 'Δεν ήμουν πιωμένος.', 'Δεν ήμουν πιωμένος.']
# 19
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν ήμουν μεθυσμένος.', 'Δεν ήμουν μεθυσμένος.', 'Δεν ήμουν μεθυσμένος.']
# 21
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν ήμουν πιωμένη.', 'Δεν ήμουν πιωμένη.', 'Δεν ήμουν πιωμένη.']
# 18
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν ήμουν μεθυσμένη.', 'Δεν ήμουν μεθυσμένη.', 'Δεν ήμουν μεθυσμένη.']
# 20
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Πήγα για ψάρεμα.', 'Πήγα για ψάρεμα.', 'Πήγα για ψάρεμα.']
# 16
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα επιβιώσω.', 'Θα επιβιώσω.', 'Θα επιβιώσω.']
# 12
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα τον πάρω.', 'Θα τον πάρω.', 'Θα τον πάρω.']
# 12
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα την πάρω.', 'Θα την πάρω.', 'Θα την πάρω.']
# 12
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δε θα ξεχάσω.', 'Δε θα ξεχάσω.', 'Δε θα ξεχάσω.']
# 13
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δε θα επιστρέψω.', 'Δε θα επιστρέψω.', 'Δε θα επιστρέψω.']
# 16
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δε θα γυρίσω.', 'Δε θα γυρίσω.', 'Δε θα γυρίσω.']
# 13
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα τους βρω.', 'Θα τους βρω.', 'Θα τους βρω.']
# 12
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα τις βρω.', 'Θα τις βρω.', 'Θα τις βρω.']
# 11
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα τα βρω.', 'Θα τα βρω.', 'Θα τα βρω.']
# 10
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα χρειαστώ βοήθεια.', 'Θα χρειαστώ βοήθεια.', 'Θα χρειαστώ βοήθεια.']
# 20
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα πληρώσω αργότερα.', 'Θα πληρώσω αργότερα.', 'Θα πληρώσω αργότερα.']
# 20
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα σου τηλεφωνήσω.', 'Θα σου τηλεφωνήσω.', 'Θα σου τηλεφωνήσω.']
# 18
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα σας τηλεφωνήσω.', 'Θα σας τηλεφωνήσω.', 'Θα σας τηλεφωνήσω.']
# 18
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα σε πυροβολήσω.', 'Θα σε πυροβολήσω.', 'Θα σε πυροβολήσω.']
# 17
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα σας πυροβολήσω.', 'Θα σας πυροβολήσω.', 'Θα σας πυροβολήσω.']
# 18
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα μείνω εδώ.', 'Θα μείνω εδώ.', 'Θα μείνω εδώ.']
# 13
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα μείνω σπίτι.', 'Θα μείνω σπίτι.', 'Θα μείνω σπίτι.']
# 15
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα σας εμπιστευτώ.', 'Θα σας εμπιστευτώ.', 'Θα σας εμπιστευτώ.']
# 18
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα σε εμπιστευτώ.', 'Θα σε εμπιστευτώ.', 'Θα σε εμπιστευτώ.']
# 17
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Θα σ' εμπιστευτώ.", "Θα σ' εμπιστευτώ.", "Θα σ' εμπιστευτώ."]
# 17
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα περιμένω εδώ.', 'Θα περιμένω εδώ.', 'Θα περιμένω εδώ.']
# 16
# 6
# 6
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είμαι η σύζυγος του Τομ.', 'Είμαι η σύζυγος του Τομ.', 'Είμαι η σύζυγος του Τομ.']
# 24
# 3
# 5
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είμαι διαβητικός.', 'Είμαι διαβητικός.', 'Είμαι διαβητικός.']
# 17
# 3
# 5
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είμαι διαβητική.', 'Είμαι διαβητική.', 'Είμαι διαβητική.']
# 16
# 5
# 6
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Εγώ είμαι ελεύθερος άνθρωπος.', 'Εγώ είμαι ελεύθερος άνθρωπος.', 'Εγώ είμαι ελεύθερος άνθρωπος.']
# 29
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Φοβάμαι πως όχι.', 'Φοβάμαι πως όχι.', 'Φοβάμαι πως όχι.']
# 16
# 3
# 5
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είμαι άθεος.', 'Είμαι άθεος.', 'Είμαι άθεος.']
# 12
# 3
# 5
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σε απολύω.', 'Σε απολύω.', 'Σε απολύω.']
# 10
# 3
# 5
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σας απολύω.', 'Σας απολύω.', 'Σας απολύω.']
# 11
# 2
# 6
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Βιάζομαι.', 'Βιάζομαι.', 'Βιάζομαι.']
# 9
# 3
# 5
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν κρύβομαι.', 'Δεν κρύβομαι.', 'Δεν κρύβομαι.']
# 13
# 3
# 5
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν αστειεύομαι.', 'Δεν αστειεύομαι.', 'Δεν αστειεύομαι.']
# 16
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είμαι συχνά εδώ.', 'Είμαι συχνά εδώ.', 'Είμαι συχνά εδώ.']
# 16
# 3
# 5
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Το διαβάζω.', 'Το διαβάζω.', 'Το διαβάζω.']
# 11
# 3
# 5
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Τον διαβάζω.', 'Τον διαβάζω.', 'Τον διαβάζω.']
# 12
# 3
# 5
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Τη διαβάζω.', 'Τη διαβάζω.', 'Τη διαβάζω.']
# 11
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είμαι άνεργος.', 'Είμαι άνεργος.', 'Είμαι άνεργος.']
# 14
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είμαι άνεργη.', 'Είμαι άνεργη.', 'Είμαι άνεργη.']
# 13
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είμαι πολύ χαρούμενος.', 'Είμαι πολύ χαρούμενος.', 'Είμαι πολύ χαρούμενος.']
# 22
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είμαι πολύ χαρούμενη.', 'Είμαι πολύ χαρούμενη.', 'Είμαι πολύ χαρούμενη.']
# 21
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είμαι πολύ κοντός.', 'Είμαι πολύ κοντός.', 'Είμαι πολύ κοντός.']
# 18
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είμαι πολύ κουρασμένος.', 'Είμαι πολύ κουρασμένος.', 'Είμαι πολύ κουρασμένος.']
# 23
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είμαι πολύ κουρασμένη.', 'Είμαι πολύ κουρασμένη.', 'Είμαι πολύ κουρασμένη.']
# 22
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ ζηλεύει;', 'Ο Τομ ζηλεύει;', 'Ο Τομ ζηλεύει;']
# 14
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ζηλεύει ο Τομ;', 'Ζηλεύει ο Τομ;', 'Ζηλεύει ο Τομ;']
# 14
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ είναι παντρεμένος;', 'Ο Τομ είναι παντρεμένος;', 'Ο Τομ είναι παντρεμένος;']
# 24
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είναι παντρεμένος ο Τομ;', 'Είναι παντρεμένος ο Τομ;', 'Είναι παντρεμένος ο Τομ;']
# 24
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είναι Αμερικάνος;', 'Είναι Αμερικάνος;', 'Είναι Αμερικάνος;']
# 17
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είναι Ιάπωνας;', 'Είναι Ιάπωνας;', 'Είναι Ιάπωνας;']
# 14
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είναι Γιαπωνέζος;', 'Είναι Γιαπωνέζος;', 'Είναι Γιαπωνέζος;']
# 17
# 2
# 4
# 9
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Κοιμάται;', 'Κοιμάται;', 'Κοιμάται;']
# 9
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είναι παντρεμένη;', 'Είναι παντρεμένη;', 'Είναι παντρεμένη;']
# 17
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είναι αυτό φυσιολογικό;', 'Είναι αυτό φυσιολογικό;', 'Είναι αυτό φυσιολογικό;']
# 23
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είναι φυσιολογικό αυτό;', 'Είναι φυσιολογικό αυτό;', 'Είναι φυσιολογικό αυτό;']
# 23
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είναι Σάββατο.', 'Είναι Σάββατο.', 'Είναι Σάββατο.']
# 14
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ήταν παράξενο.', 'Ήταν παράξενο.', 'Ήταν παράξενο.']
# 14
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δνε ήταν αλήθεια.', 'Δνε ήταν αλήθεια.', 'Δνε ήταν αλήθεια.']
# 17
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα είναι έτοιμος.', 'Θα είναι έτοιμος.', 'Θα είναι έτοιμος.']
# 17
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα είναι έτοιμο.', 'Θα είναι έτοιμο.', 'Θα είναι έτοιμο.']
# 16
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα είναι έτοιμη.', 'Θα είναι έτοιμη.', 'Θα είναι έτοιμη.']
# 16
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Θα 'ναι έτοιμος.", "Θα 'ναι έτοιμος.", "Θα 'ναι έτοιμος."]
# 16
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Θα 'ναι έτοιμη.", "Θα 'ναι έτοιμη.", "Θα 'ναι έτοιμη."]
# 15
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Θα 'ναι έτοιμο.", "Θα 'ναι έτοιμο.", "Θα 'ναι έτοιμο."]
# 15
# 3
# 5
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είναι ολοκαίνουργιο.', 'Είναι ολοκαίνουργιο.', 'Είναι ολοκαίνουργιο.']
# 20
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είναι επικίνδυνο!', 'Είναι επικίνδυνο!', 'Είναι επικίνδυνο!']
# 17
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Είν' επικίνδυνο!", "Είν' επικίνδυνο!", "Είν' επικίνδυνο!"]
# 16
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είναι λάθος.', 'Είναι λάθος.', 'Είναι λάθος.']
# 12
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν είναι φτηνός.', 'Δεν είναι φτηνός.', 'Δεν είναι φτηνός.']
# 17
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν είναι φτηνή.', 'Δεν είναι φτηνή.', 'Δεν είναι φτηνή.']
# 16
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν είναι φτηνό.', 'Δεν είναι φτηνό.', 'Δεν είναι φτηνό.']
# 16
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν είναι αστείο.', 'Δεν είναι αστείο.', 'Δεν είναι αστείο.']
# 17
# 4
# 6
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Εξαρτάται από σένα.', 'Εξαρτάται από σένα.', 'Εξαρτάται από σένα.']
# 19
# 3
# 5
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σειρά σας.', 'Σειρά σας.', 'Σειρά σας.']
# 10
# 4
# 3
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Συνέχισε να ψάχνεις.', 'Συνέχισε να ψάχνεις.', 'Συνέχισε να ψάχνεις.']
# 20
# 4
# 3
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Συνεχίστε να ψάχνετε.', 'Συνεχίστε να ψάχνετε.', 'Συνεχίστε να ψάχνετε.']
# 21
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Άσ' το εκεί.", "Άσ' το εκεί.", "Άσ' το εκεί."]
# 12
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Αφήστε το εκεί.', 'Αφήστε το εκεί.', 'Αφήστε το εκεί.']
# 15
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Άφησε το εκεί.', 'Άφησε το εκεί.', 'Άφησε το εκεί.']
# 14
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Παράτα με!', 'Παράτα με!', 'Παράτα με!']
# 10
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Άσε με ήσυχο!', 'Άσε με ήσυχο!', 'Άσε με ήσυχο!']
# 13
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ας μην κολυμπήσουμε.', 'Ας μην κολυμπήσουμε.', 'Ας μην κολυμπήσουμε.']
# 20
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Η ζωή είναι άδικη.', 'Η ζωή είναι άδικη.', 'Η ζωή είναι άδικη.']
# 18
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Κλείδωσε τις πόρτες.', 'Κλείδωσε τις πόρτες.', 'Κλείδωσε τις πόρτες.']
# 20
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Κλειδώστε τις πόρτες.', 'Κλειδώστε τις πόρτες.', 'Κλειδώστε τις πόρτες.']
# 21
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Κοιτάξτε το μπράτσο μου.', 'Κοιτάξτε το μπράτσο μου.', 'Κοιτάξτε το μπράτσο μου.']
# 24
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Πιο δυνατά, παρακαλώ.', 'Πιο δυνατά, παρακαλώ.', 'Πιο δυνατά, παρακαλώ.']
# 21
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Η Μαίρη είναι ξανθιά.', 'Η Μαίρη είναι ξανθιά.', 'Η Μαίρη είναι ξανθιά.']
# 21
# 6
# 5
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα μπορούσα να το χρησιμοποιήσω;', 'Θα μπορούσα να το χρησιμοποιήσω;', 'Θα μπορούσα να το χρησιμοποιήσω;']
# 32
# 6
# 5
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Το αυτοκίνητό μου είναι βρόμικο.', 'Το αυτοκίνητό μου είναι βρόμικο.', 'Το αυτοκίνητό μου είναι βρόμικο.']
# 32
# 6
# 5
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Το αμάξι μου είναι βρόμικο.', 'Το αμάξι μου είναι βρόμικο.', 'Το αμάξι μου είναι βρόμικο.']
# 27
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Οι αρθρώσεις μου πονάνε.', 'Οι αρθρώσεις μου πονάνε.', 'Οι αρθρώσεις μου πονάνε.']
# 24
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Πονάνε οι αρθρώσεις μου.', 'Πονάνε οι αρθρώσεις μου.', 'Πονάνε οι αρθρώσεις μου.']
# 24
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Με τρώει η μύτη μου.', 'Με τρώει η μύτη μου.', 'Με τρώει η μύτη μου.']
# 20
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μου πονά το δόντι.', 'Μου πονά το δόντι.', 'Μου πονά το δόντι.']
# 18
# 4
# 3
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Κανείς δε γέλασε.', 'Κανείς δε γέλασε.', 'Κανείς δε γέλασε.']
# 17
# 4
# 3
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Κανείς δεν ακούει.', 'Κανείς δεν ακούει.', 'Κανείς δεν ακούει.']
# 18
# 5
# 3
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Κανείς δε θα ξέρει.', 'Κανείς δε θα ξέρει.', 'Κανείς δε θα ξέρει.']
# 19
# 5
# 3
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Κανείς δε θα μάθει.', 'Κανείς δε θα μάθει.', 'Κανείς δε θα μάθει.']
# 19
# 5
# 3
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δε θα μάθει κάνεις.', 'Δε θα μάθει κάνεις.', 'Δε θα μάθει κάνεις.']
# 19
# 5
# 3
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δε θα ξέρει κανείς.', 'Δε θα ξέρει κανείς.', 'Δε θα ξέρει κανείς.']
# 19
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Τώρα θυμάμαι.', 'Τώρα θυμάμαι.', 'Τώρα θυμάμαι.']
# 13
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Άνοιξε τα μάτια σου.', 'Άνοιξε τα μάτια σου.', 'Άνοιξε τα μάτια σου.']
# 20
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σε παρακαλώ, βοήθησέ με.', 'Σε παρακαλώ, βοήθησέ με.', 'Σε παρακαλώ, βοήθησέ με.']
# 24
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σας παρακαλώ, βοηθήστε με.', 'Σας παρακαλώ, βοηθήστε με.', 'Σας παρακαλώ, βοηθήστε με.']
# 26
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Τα λέμε Δευτέρα.', 'Τα λέμε Δευτέρα.', 'Τα λέμε Δευτέρα.']
# 16
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Τον λατρεύει.', 'Τον λατρεύει.', 'Τον λατρεύει.']
# 13
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Έδωσε χρήματα.', 'Έδωσε χρήματα.', 'Έδωσε χρήματα.']
# 14
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Έδωσε λεφτά.', 'Έδωσε λεφτά.', 'Έδωσε λεφτά.']
# 12
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Κάνει δίαιτα.', 'Κάνει δίαιτα.', 'Κάνει δίαιτα.']
# 13
# 2
# 4
# 9
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μιλάει.', 'Μιλάει.', 'Μιλάει.']
# 7
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν είναι φτωχή.', 'Δεν είναι φτωχή.', 'Δεν είναι φτωχή.']
# 16
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Τον φίλησε.', 'Τον φίλησε.', 'Τον φίλησε.']
# 11
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Της αρέσει το κρασί.', 'Της αρέσει το κρασί.', 'Της αρέσει το κρασί.']
# 20
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Τραγουδάει καλά.', 'Τραγουδάει καλά.', 'Τραγουδάει καλά.']
# 16
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Εργάζεται σκληρά.', 'Εργάζεται σκληρά.', 'Εργάζεται σκληρά.']
# 17
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δουλεύει σκληρά.', 'Δουλεύει σκληρά.', 'Δουλεύει σκληρά.']
# 16
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είναι διαζευγμένη.', 'Είναι διαζευγμένη.', 'Είναι διαζευγμένη.']
# 18
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Πρέπει να το κάνω;', 'Πρέπει να το κάνω;', 'Πρέπει να το κάνω;']
# 18
# 4
# 3
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σταμάτα να κουτσομπολεύεις.', 'Σταμάτα να κουτσομπολεύεις.', 'Σταμάτα να κουτσομπολεύεις.']
# 27
# 4
# 3
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σταματήστε να κουτσομπολεύετε.', 'Σταματήστε να κουτσομπολεύετε.', 'Σταματήστε να κουτσομπολεύετε.']
# 30
# 4
# 3
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Πάψε να δυσφορείς.', 'Πάψε να δυσφορείς.', 'Πάψε να δυσφορείς.']
# 18
# 4
# 3
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σταμάτα να γογγύζεις.', 'Σταμάτα να γογγύζεις.', 'Σταμάτα να γογγύζεις.']
# 21
# 5
# 3
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Πάψε ν' αντιστέκεσαι!", "Πάψε ν' αντιστέκεσαι!", "Πάψε ν' αντιστέκεσαι!"]
# 21
# 5
# 3
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Πάψτε ν' αντιστέκεστε!", "Πάψτε ν' αντιστέκεστε!", "Πάψτε ν' αντιστέκεστε!"]
# 22
# 5
# 3
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Σταμάτα ν' αντιστέκεσαι!", "Σταμάτα ν' αντιστέκεσαι!", "Σταμάτα ν' αντιστέκεσαι!"]
# 24
# 5
# 3
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Σταματήστε ν' αντιστέκεστε!", "Σταματήστε ν' αντιστέκεστε!", "Σταματήστε ν' αντιστέκεστε!"]
# 27
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Με το πάσο σου.', 'Με το πάσο σου.', 'Με το πάσο σου.']
# 15
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Με το πάσο σας.', 'Με το πάσο σας.', 'Με το πάσο σας.']
# 15
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Πες την αλήθεια.', 'Πες την αλήθεια.', 'Πες την αλήθεια.']
# 16
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Πείτε την αλήθεια.', 'Πείτε την αλήθεια.', 'Πείτε την αλήθεια.']
# 18
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Αυτό θ' αλλάξει.", "Αυτό θ' αλλάξει.", "Αυτό θ' αλλάξει."]
# 16
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Αυτό θα αλλάξει.', 'Αυτό θα αλλάξει.', 'Αυτό θα αλλάξει.']
# 16
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Θ' αλλάξει αυτό.", "Θ' αλλάξει αυτό.", "Θ' αλλάξει αυτό."]
# 16
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα αλλάξει αυτό.', 'Θα αλλάξει αυτό.', 'Θα αλλάξει αυτό.']
# 16
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Η στέγη στάζει.', 'Η στέγη στάζει.', 'Η στέγη στάζει.']
# 15
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Τα μάτια τους συναντήθηκαν.', 'Τα μάτια τους συναντήθηκαν.', 'Τα μάτια τους συναντήθηκαν.']
# 27
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Αυτά είναι δικά μου.', 'Αυτά είναι δικά μου.', 'Αυτά είναι δικά μου.']
# 20
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Αυτοί είναι δικοί μας.', 'Αυτοί είναι δικοί μας.', 'Αυτοί είναι δικοί μας.']
# 22
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Αυτά είναι δικά μας.', 'Αυτά είναι δικά μας.', 'Αυτά είναι δικά μας.']
# 20
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Αυτές είναι δικές μας.', 'Αυτές είναι δικές μας.', 'Αυτές είναι δικές μας.']
# 22
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είναι χαρούμενοι.', 'Είναι χαρούμενοι.', 'Είναι χαρούμενοι.']
# 17
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είναι ευτυχισμένοι.', 'Είναι ευτυχισμένοι.', 'Είναι ευτυχισμένοι.']
# 19
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μπορούν να το κάνουν.', 'Μπορούν να το κάνουν.', 'Μπορούν να το κάνουν.']
# 21
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σε μίσησαν.', 'Σε μίσησαν.', 'Σε μίσησαν.']
# 11
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σας μίσησαν.', 'Σας μίσησαν.', 'Σας μίσησαν.']
# 12
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Έχουν έρθει.', 'Έχουν έρθει.', 'Έχουν έρθει.']
# 12
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Έχουν κρασί.', 'Έχουν κρασί.', 'Έχουν κρασί.']
# 12
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Μόλις έφυγαν.', 'Μόλις έφυγαν.', 'Μόλις έφυγαν.']
# 13
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Χρειάζονται βοήθεια.', 'Χρειάζονται βοήθεια.', 'Χρειάζονται βοήθεια.']
# 20
# 2
# 3
# 8
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Τσακώθηκαν.', 'Τσακώθηκαν.', 'Τσακώθηκαν.']
# 11
# 2
# 3
# 8
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Διαπληκτίστηκαν.', 'Διαπληκτίστηκαν.', 'Διαπληκτίστηκαν.']
# 16
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Το κατέστρεψαν.', 'Το κατέστρεψαν.', 'Το κατέστρεψαν.']
# 15
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Τον κατέστρεψαν.', 'Τον κατέστρεψαν.', 'Τον κατέστρεψαν.']
# 16
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Την κατέστρεψαν.', 'Την κατέστρεψαν.', 'Την κατέστρεψαν.']
# 16
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ήταν απασχολημένες.', 'Ήταν απασχολημένες.', 'Ήταν απασχολημένες.']
# 19
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ήταν απασχολημένα.', 'Ήταν απασχολημένα.', 'Ήταν απασχολημένα.']
# 18
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ήταν απασχολημένοι.', 'Ήταν απασχολημένοι.', 'Ήταν απασχολημένοι.']
# 19
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ήταν δικοί μου.', 'Ήταν δικοί μου.', 'Ήταν δικοί μου.']
# 15
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ήταν δικές μου.', 'Ήταν δικές μου.', 'Ήταν δικές μου.']
# 15
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ήταν δικά μου.', 'Ήταν δικά μου.', 'Ήταν δικά μου.']
# 14
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα έρθουν.', 'Θα έρθουν.', 'Θα έρθουν.']
# 10
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Θα 'ρθουν.", "Θα 'ρθουν.", "Θα 'ρθουν."]
# 10
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα βοηθήσουν.', 'Θα βοηθήσουν.', 'Θα βοηθήσουν.']
# 13
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δουλεύουν σκληρά.', 'Δουλεύουν σκληρά.', 'Δουλεύουν σκληρά.']
# 17
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Εργάζονται σκληρά.', 'Εργάζονται σκληρά.', 'Εργάζονται σκληρά.']
# 18
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Αυτό το σκυλί δαγκώνει.', 'Αυτό το σκυλί δαγκώνει.', 'Αυτό το σκυλί δαγκώνει.']
# 23
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Αυτός ο σκύλος δαγκώνει.', 'Αυτός ο σκύλος δαγκώνει.', 'Αυτός ο σκύλος δαγκώνει.']
# 24
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Αυτό είναι ένα αχλάδι.', 'Αυτό είναι ένα αχλάδι.', 'Αυτό είναι ένα αχλάδι.']
# 22
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Αυτό είναι σπασμένο.', 'Αυτό είναι σπασμένο.', 'Αυτό είναι σπασμένο.']
# 20
# 6
# 5
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Αυτός είναι ο γάτος μου.', 'Αυτός είναι ο γάτος μου.', 'Αυτός είναι ο γάτος μου.']
# 24
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Εισιτήριο, παρακαλώ.', 'Εισιτήριο, παρακαλώ.', 'Εισιτήριο, παρακαλώ.']
# 20
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ώρα να σηκωθείς.', 'Ώρα να σηκωθείς.', 'Ώρα να σηκωθείς.']
# 16
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο χρόνος θα δείξει.', 'Ο χρόνος θα δείξει.', 'Ο χρόνος θα δείξει.']
# 19
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ σε λατρεύει.', 'Ο Τομ σε λατρεύει.', 'Ο Τομ σε λατρεύει.']
# 18
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ σας λατρεύει.', 'Ο Τομ σας λατρεύει.', 'Ο Τομ σας λατρεύει.']
# 19
# 4
# 3
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ πλησίασε.', 'Ο Τομ πλησίασε.', 'Ο Τομ πλησίασε.']
# 15
# 7
# 5
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ δεν μπορεί να περπατήσει.', 'Ο Τομ δεν μπορεί να περπατήσει.', 'Ο Τομ δεν μπορεί να περπατήσει.']
# 31
# 7
# 5
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ δεν μπορεί να βαδίσει.', 'Ο Τομ δεν μπορεί να βαδίσει.', 'Ο Τομ δεν μπορεί να βαδίσει.']
# 28
# 7
# 5
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν μπορεί να περπατήσει ο Τομ.', 'Δεν μπορεί να περπατήσει ο Τομ.', 'Δεν μπορεί να περπατήσει ο Τομ.']
# 31
# 7
# 5
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν μπορεί να βαδίσει ο Τομ.', 'Δεν μπορεί να βαδίσει ο Τομ.', 'Δεν μπορεί να βαδίσει ο Τομ.']
# 28
# 4
# 3
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ παραπονέθηκε.', 'Ο Τομ παραπονέθηκε.', 'Ο Τομ παραπονέθηκε.']
# 19
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ μαγειρεύει καλά.', 'Ο Τομ μαγειρεύει καλά.', 'Ο Τομ μαγειρεύει καλά.']
# 22
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ πέθανε νέος.', 'Ο Τομ πέθανε νέος.', 'Ο Τομ πέθανε νέος.']
# 18
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ τρώει πολύ.', 'Ο Τομ τρώει πολύ.', 'Ο Τομ τρώει πολύ.']
# 17
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Τρώει πολύ ο Τομ.', 'Τρώει πολύ ο Τομ.', 'Τρώει πολύ ο Τομ.']
# 17
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ αισθάνθηκε κουρασμένος.', 'Ο Τομ αισθάνθηκε κουρασμένος.', 'Ο Τομ αισθάνθηκε κουρασμένος.']
# 29
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ απόλυσε τη Μαίρη.', 'Ο Τομ απόλυσε τη Μαίρη.', 'Ο Τομ απόλυσε τη Μαίρη.']
# 23
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ απέλυσε τη Μαίρη.', 'Ο Τομ απέλυσε τη Μαίρη.', 'Ο Τομ απέλυσε τη Μαίρη.']
# 23
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ με συγχώρεσε.', 'Ο Τομ με συγχώρεσε.', 'Ο Τομ με συγχώρεσε.']
# 19
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ με συγχώρησε.', 'Ο Τομ με συγχώρησε.', 'Ο Τομ με συγχώρησε.']
# 19
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ βρήκε τη Μαίρη.', 'Ο Τομ βρήκε τη Μαίρη.', 'Ο Τομ βρήκε τη Μαίρη.']
# 21
# 6
# 5
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ έχει μια Φορντ.', 'Ο Τομ έχει μια Φορντ.', 'Ο Τομ έχει μια Φορντ.']
# 21
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ μίσησε τη Μαίρη.', 'Ο Τομ μίσησε τη Μαίρη.', 'Ο Τομ μίσησε τη Μαίρη.']
# 22
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ μισούσε τη Μαίρη.', 'Ο Τομ μισούσε τη Μαίρη.', 'Ο Τομ μισούσε τη Μαίρη.']
# 23
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ μισεί τη Μαίρη.', 'Ο Τομ μισεί τη Μαίρη.', 'Ο Τομ μισεί τη Μαίρη.']
# 21
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ μισεί τα σκυλιά.', 'Ο Τομ μισεί τα σκυλιά.', 'Ο Τομ μισεί τα σκυλιά.']
# 22
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ προσέλαβε τη Μαίρη.', 'Ο Τομ προσέλαβε τη Μαίρη.', 'Ο Τομ προσέλαβε τη Μαίρη.']
# 25
# 4
# 3
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ αυτοσχεδίασε.', 'Ο Τομ αυτοσχεδίασε.', 'Ο Τομ αυτοσχεδίασε.']
# 19
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ μαγειρεύει.', 'Ο Τομ μαγειρεύει.', 'Ο Τομ μαγειρεύει.']
# 17
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ είναι κυνικός.', 'Ο Τομ είναι κυνικός.', 'Ο Τομ είναι κυνικός.']
# 20
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ χορεύει.', 'Ο Τομ χορεύει.', 'Ο Τομ χορεύει.']
# 14
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Χορεύει ο Τομ.', 'Χορεύει ο Τομ.', 'Χορεύει ο Τομ.']
# 14
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ κάνει δίαιτα.', 'Ο Τομ κάνει δίαιτα.', 'Ο Τομ κάνει δίαιτα.']
# 19
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Κάνει δίαιτα ο Τομ.', 'Κάνει δίαιτα ο Τομ.', 'Κάνει δίαιτα ο Τομ.']
# 19
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ οδηγάει.', 'Ο Τομ οδηγάει.', 'Ο Τομ οδηγάει.']
# 14
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ ξεσκονίζει.', 'Ο Τομ ξεσκονίζει.', 'Ο Τομ ξεσκονίζει.']
# 17
# 8
# 5
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Ο Τομ είναι τ' αφεντικό μου.", "Ο Τομ είναι τ' αφεντικό μου.", "Ο Τομ είναι τ' αφεντικό μου."]
# 28
# 7
# 5
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ είναι ο τύπος μου.', 'Ο Τομ είναι ο τύπος μου.', 'Ο Τομ είναι ο τύπος μου.']
# 24
# 8
# 5
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Ο Τομ είν' ο τύπος μου.", "Ο Τομ είν' ο τύπος μου.", "Ο Τομ είν' ο τύπος μου."]
# 23
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ είναι υπομονετικός.', 'Ο Τομ είναι υπομονετικός.', 'Ο Τομ είναι υπομονετικός.']
# 25
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ είναι δημοφιλής.', 'Ο Τομ είναι δημοφιλής.', 'Ο Τομ είναι δημοφιλής.']
# 22
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ προσεύχεται.', 'Ο Τομ προσεύχεται.', 'Ο Τομ προσεύχεται.']
# 18
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ διαβάζει.', 'Ο Τομ διαβάζει.', 'Ο Τομ διαβάζει.']
# 15
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ τρέχει.', 'Ο Τομ τρέχει.', 'Ο Τομ τρέχει.']
# 13
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ τρέμει.', 'Ο Τομ τρέμει.', 'Ο Τομ τρέμει.']
# 13
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ ξυρίζεται.', 'Ο Τομ ξυρίζεται.', 'Ο Τομ ξυρίζεται.']
# 16
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ τραγουδάει.', 'Ο Τομ τραγουδάει.', 'Ο Τομ τραγουδάει.']
# 17
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ είναι εξυπνότερος.', 'Ο Τομ είναι εξυπνότερος.', 'Ο Τομ είναι εξυπνότερος.']
# 24
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Ο Τομ είν' εξυπνότερος.", "Ο Τομ είν' εξυπνότερος.", "Ο Τομ είν' εξυπνότερος."]
# 23
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ είναι πιο έξυπνος.', 'Ο Τομ είναι πιο έξυπνος.', 'Ο Τομ είναι πιο έξυπνος.']
# 24
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ καπνίζει.', 'Ο Τομ καπνίζει.', 'Ο Τομ καπνίζει.']
# 15
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ είναι κακομαθημένος.', 'Ο Τομ είναι κακομαθημένος.', 'Ο Τομ είναι κακομαθημένος.']
# 26
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ κερδίζει.', 'Ο Τομ κερδίζει.', 'Ο Τομ κερδίζει.']
# 15
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ νικάει.', 'Ο Τομ νικάει.', 'Ο Τομ νικάει.']
# 13
# 6
# 5
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ δεν είναι δίκαιος.', 'Ο Τομ δεν είναι δίκαιος.', 'Ο Τομ δεν είναι δίκαιος.']
# 24
# 6
# 5
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν είναι δίκαιος ο Τομ.', 'Δεν είναι δίκαιος ο Τομ.', 'Δεν είναι δίκαιος ο Τομ.']
# 24
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ ξέρει τη Μαίρη.', 'Ο Τομ ξέρει τη Μαίρη.', 'Ο Τομ ξέρει τη Μαίρη.']
# 21
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ γνωρίζει τη Μαίρη.', 'Ο Τομ γνωρίζει τη Μαίρη.', 'Ο Τομ γνωρίζει τη Μαίρη.']
# 24
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Η Μαίρη άρεσε στον Τομ.', 'Η Μαίρη άρεσε στον Τομ.', 'Η Μαίρη άρεσε στον Τομ.']
# 23
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Η Μαίρη αρέσει στον Τομ.', 'Η Μαίρη αρέσει στον Τομ.', 'Η Μαίρη αρέσει στον Τομ.']
# 24
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Στον Τομ αρέσουν οι γάτες.', 'Στον Τομ αρέσουν οι γάτες.', 'Στον Τομ αρέσουν οι γάτες.']
# 26
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ αγάπησε τη Μαίρη.', 'Ο Τομ αγάπησε τη Μαίρη.', 'Ο Τομ αγάπησε τη Μαίρη.']
# 23
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ αγαπούσε τη Μαίρη.', 'Ο Τομ αγαπούσε τη Μαίρη.', 'Ο Τομ αγαπούσε τη Μαίρη.']
# 24
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ αγαπά τη Μαίρη.', 'Ο Τομ αγαπά τη Μαίρη.', 'Ο Τομ αγαπά τη Μαίρη.']
# 21
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ αγαπάει τη Μαίρη.', 'Ο Τομ αγαπάει τη Μαίρη.', 'Ο Τομ αγαπάει τη Μαίρη.']
# 23
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ χρειάζεται τη Μαίρη.', 'Ο Τομ χρειάζεται τη Μαίρη.', 'Ο Τομ χρειάζεται τη Μαίρη.']
# 26
# 4
# 3
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ θυμήθηκε.', 'Ο Τομ θυμήθηκε.', 'Ο Τομ θυμήθηκε.']
# 15
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ φαινόταν ντροπαλός.', 'Ο Τομ φαινόταν ντροπαλός.', 'Ο Τομ φαινόταν ντροπαλός.']
# 25
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ κοιμήθηκε αργά.', 'Ο Τομ κοιμήθηκε αργά.', 'Ο Τομ κοιμήθηκε αργά.']
# 21
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ το ξεκίνησε.', 'Ο Τομ το ξεκίνησε.', 'Ο Τομ το ξεκίνησε.']
# 18
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ κράτησε σημειώσεις.', 'Ο Τομ κράτησε σημειώσεις.', 'Ο Τομ κράτησε σημειώσεις.']
# 25
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Ο Τομ σ' εμπιστεύεται.", "Ο Τομ σ' εμπιστεύεται.", "Ο Τομ σ' εμπιστεύεται."]
# 22
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ σε εμπιστεύεται.', 'Ο Τομ σε εμπιστεύεται.', 'Ο Τομ σε εμπιστεύεται.']
# 22
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ σας εμπιστεύεται.', 'Ο Τομ σας εμπιστεύεται.', 'Ο Τομ σας εμπιστεύεται.']
# 23
# 4
# 3
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ κατάλαβε.', 'Ο Τομ κατάλαβε.', 'Ο Τομ κατάλαβε.']
# 15
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ θέλει τη Μαίρη.', 'Ο Τομ θέλει τη Μαίρη.', 'Ο Τομ θέλει τη Μαίρη.']
# 21
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ ήταν διάσημος.', 'Ο Τομ ήταν διάσημος.', 'Ο Τομ ήταν διάσημος.']
# 20
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ πεινούσε.', 'Ο Τομ πεινούσε.', 'Ο Τομ πεινούσε.']
# 15
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Πεινούσε ο Τομ.', 'Πεινούσε ο Τομ.', 'Πεινούσε ο Τομ.']
# 15
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ θα χορέψει.', 'Ο Τομ θα χορέψει.', 'Ο Τομ θα χορέψει.']
# 17
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα χορέψει ο Τομ.', 'Θα χορέψει ο Τομ.', 'Θα χορέψει ο Τομ.']
# 17
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ θα οδηγήσει.', 'Ο Τομ θα οδηγήσει.', 'Ο Τομ θα οδηγήσει.']
# 18
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα οδηγήσει ο Τομ.', 'Θα οδηγήσει ο Τομ.', 'Θα οδηγήσει ο Τομ.']
# 18
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Ο Τομ θ' αρχίσει.", "Ο Τομ θ' αρχίσει.", "Ο Τομ θ' αρχίσει."]
# 17
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ θα ξεκινήσει.', 'Ο Τομ θα ξεκινήσει.', 'Ο Τομ θα ξεκινήσει.']
# 19
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Θ' αρχίσει ο Τομ.", "Θ' αρχίσει ο Τομ.", "Θ' αρχίσει ο Τομ."]
# 17
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα ξεκινήσει ο Τομ.', 'Θα ξεκινήσει ο Τομ.', 'Θα ξεκινήσει ο Τομ.']
# 19
# 6
# 5
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ δε θα έρθει.', 'Ο Τομ δε θα έρθει.', 'Ο Τομ δε θα έρθει.']
# 18
# 7
# 5
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Ο Τομ δε θα 'ρθει.", "Ο Τομ δε θα 'ρθει.", "Ο Τομ δε θα 'ρθει."]
# 18
# 6
# 5
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δε θα ΄ρθει ο Τομ.', 'Δε θα ΄ρθει ο Τομ.', 'Δε θα ΄ρθει ο Τομ.']
# 18
# 6
# 5
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δε θα έρθει ο Τομ.', 'Δε θα έρθει ο Τομ.', 'Δε θα έρθει ο Τομ.']
# 18
# 6
# 5
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ δε θα μείνει.', 'Ο Τομ δε θα μείνει.', 'Ο Τομ δε θα μείνει.']
# 19
# 6
# 5
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δε θα μείνει ο Τομ.', 'Δε θα μείνει ο Τομ.', 'Δε θα μείνει ο Τομ.']
# 19
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ εργάζεται σκληρά.', 'Ο Τομ εργάζεται σκληρά.', 'Ο Τομ εργάζεται σκληρά.']
# 23
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ δουλεύει σκληρά.', 'Ο Τομ δουλεύει σκληρά.', 'Ο Τομ δουλεύει σκληρά.']
# 22
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δουλεύει σκληρά ο Τομ.', 'Δουλεύει σκληρά ο Τομ.', 'Δουλεύει σκληρά ο Τομ.']
# 22
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Εργάζεται σκληρά ο Τομ.', 'Εργάζεται σκληρά ο Τομ.', 'Εργάζεται σκληρά ο Τομ.']
# 23
# 5
# 3
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ θα επιβιώσει.', 'Ο Τομ θα επιβιώσει.', 'Ο Τομ θα επιβιώσει.']
# 19
# 5
# 3
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Θα επιβιώσει ο Τομ.', 'Θα επιβιώσει ο Τομ.', 'Θα επιβιώσει ο Τομ.']
# 19
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ είναι Καναδός.', 'Ο Τομ είναι Καναδός.', 'Ο Τομ είναι Καναδός.']
# 20
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ είναι Καναδέζος.', 'Ο Τομ είναι Καναδέζος.', 'Ο Τομ είναι Καναδέζος.']
# 22
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ ονειρεύεται.', 'Ο Τομ ονειρεύεται.', 'Ο Τομ ονειρεύεται.']
# 18
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ κοιμάται.', 'Ο Τομ κοιμάται.', 'Ο Τομ κοιμάται.']
# 15
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Κοιμάται ο Τομ.', 'Κοιμάται ο Τομ.', 'Κοιμάται ο Τομ.']
# 15
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ διαβάζει.', 'Ο Τομ διαβάζει.', 'Ο Τομ διαβάζει.']
# 15
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ μελετάει.', 'Ο Τομ μελετάει.', 'Ο Τομ μελετάει.']
# 15
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Ο Τομ κολυμπάει.', 'Ο Τομ κολυμπάει.', 'Ο Τομ κολυμπάει.']
# 16
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Πλύνε τα πόδια σου.', 'Πλύνε τα πόδια σου.', 'Πλύνε τα πόδια σου.']
# 19
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Είμαστε γιατροί.', 'Είμαστε γιατροί.', 'Είμαστε γιατροί.']
# 16
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σας πιστεύουμε.', 'Σας πιστεύουμε.', 'Σας πιστεύουμε.']
# 15
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σε πιστεύουμε.', 'Σε πιστεύουμε.', 'Σε πιστεύουμε.']
# 14
# 3
# 5
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δεν ξέραμε.', 'Δεν ξέραμε.', 'Δεν ξέραμε.']
# 11
# 3
# 5
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Δε γνωρίζαμε.', 'Δε γνωρίζαμε.', 'Δε γνωρίζαμε.']
# 13
# 2
# 4
# 9
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Παντρευτήκαμε.', 'Παντρευτήκαμε.', 'Παντρευτήκαμε.']
# 14
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Έχουμε αποτύχει.', 'Έχουμε αποτύχει.', 'Έχουμε αποτύχει.']
# 16
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Τα βοηθήσαμε.', 'Τα βοηθήσαμε.', 'Τα βοηθήσαμε.']
# 13
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Τους βοηθήσαμε.', 'Τους βοηθήσαμε.', 'Τους βοηθήσαμε.']
# 15
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Τις βοηθήσαμε.', 'Τις βοηθήσαμε.', 'Τις βοηθήσαμε.']
# 14
# 3
# 5
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Γελάμε πολύ.', 'Γελάμε πολύ.', 'Γελάμε πολύ.']
# 12
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Πρέπει να φύγουμε τώρα.', 'Πρέπει να φύγουμε τώρα.', 'Πρέπει να φύγουμε τώρα.']
# 23
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["Σ' εμπιστευτήκαμε.", "Σ' εμπιστευτήκαμε.", "Σ' εμπιστευτήκαμε."]
# 18
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Σε εμπιστευτήκαμε.', 'Σε εμπιστευτήκαμε.', 'Σε εμπιστευτήκαμε.']
# 18

# %%
data_bundle.get_dataset('dev')

# %% [markdown]
# # 预处理

# %%
from fastNLP import Vocabulary

# %%
def process(data_bundle: DataBundle) -> DataBundle:
    data_bundle = _concat_clip(data_bundle
                                   , max_len=max_len
                                   , concat_field_name='raw_chars')

    src_vocab = Vocabulary()
    src_vocab.from_dataset(*[ds for name, ds in data_bundle.iter_datasets() 
                             if 'train' in name],
                           field_name='raw_chars',
                           no_create_entry_dataset=[ds for name, ds in data_bundle.iter_datasets()
                                                    if 'train' not in name]
                           )
    src_vocab.index_dataset(*data_bundle.datasets.values()
                            , field_name='raw_chars', new_field_name='chars')
    data_bundle.set_vocab(src_vocab, 'chars')

    data_bundle.set_ignore_type('raw_chars', 'answers', flag=True)
    data_bundle.set_input('chars')
    data_bundle.set_target('raw_chars', 
                           'answers',
                           'target_start',
                           'target_end',
                           'context_len')

    return data_bundle

# %%
data_bundle=process(data_bundle)
# Out:
# 12
# 6
# 21
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我试着尽可能好,我可以。', '我试着尽可能好,我可以。', '我试着尽可能好,我可以。']
# 12
# 14
# 5
# 22
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['幸福不是真正的可预测的情绪。', '幸福不是真正的可预测的情绪。', '幸福不是真正的可预测的情绪。']
# 14
# 13
# 5
# 21
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['耻辱是一种常见的人类情绪。', '耻辱是一种常见的人类情绪。', '耻辱是一种常见的人类情绪。']
# 13
# 6
# 6
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你能感觉到吗', '你能感觉到吗', '你能感觉到吗']
# 6
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你感觉。', '你感觉。', '你感觉。']
# 4
# 3
# 3
# 9
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你感觉', '你感觉', '你感觉']
# 3
# 4
# 3
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你觉得爱', '你觉得爱', '你觉得爱']
# 4
# 12
# 4
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我们都对自己的感情负责。', '我们都对自己的感情负责。', '我们都对自己的感情负责。']
# 12
# 22
# 6
# 31
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我没有任何情绪,所以我不能真正感到悲伤这样。', '我没有任何情绪,所以我不能真正感到悲伤这样。', '我没有任何情绪,所以我不能真正感到悲伤这样。']
# 22
# 3
# 2
# 8
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你感觉', '你感觉', '你感觉']
# 3
# 20
# 7
# 30
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['恐惧是一种人类的情感,机器人不经历恐惧。', '恐惧是一种人类的情感,机器人不经历恐惧。', '恐惧是一种人类的情感,机器人不经历恐惧。']
# 20
# 8
# 7
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我没有什么感情。', '我没有什么感情。', '我没有什么感情。']
# 8
# 12
# 6
# 21
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['悲伤不是我想体验的情感。', '悲伤不是我想体验的情感。', '悲伤不是我想体验的情感。']
# 12
# 7
# 7
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['什么让你伤心。', '什么让你伤心。', '什么让你伤心。']
# 7
# 28
# 6
# 37
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['愤怒是一个困难的人类情绪,作为一个,我试图控制我的愤怒。', '愤怒是一个困难的人类情绪,作为一个,我试图控制我的愤怒。', '愤怒是一个困难的人类情绪,作为一个,我试图控制我的愤怒。']
# 28
# 13
# 5
# 21
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['担心是一种常见的人类情绪。', '担心是一种常见的人类情绪。', '担心是一种常见的人类情绪。']
# 13
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你讨厌。', '你讨厌。', '你讨厌。']
# 4
# 7
# 4
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['人类高度情感。', '人类高度情感。', '人类高度情感。']
# 7
# 8
# 4
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['尽量不要太害怕。', '尽量不要太害怕。', '尽量不要太害怕。']
# 8
# 8
# 2
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['机器人很有趣..', '机器人很有趣..', '机器人很有趣..']
# 8
# 13
# 4
# 20
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['愤怒不是我可以体验的情感。', '愤怒不是我可以体验的情感。', '愤怒不是我可以体验的情感。']
# 13
# 8
# 7
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['机器人不能冒犯。', '机器人不能冒犯。', '机器人不能冒犯。']
# 8
# 11
# 3
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['人们总是担心事情,但是', '人们总是担心事情,但是', '人们总是担心事情,但是']
# 11
# 10
# 3
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['机器人永远不会撒谎。', '机器人永远不会撒谎。', '机器人永远不会撒谎。']
# 10
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我没有恐惧。', '我没有恐惧。', '我没有恐惧。']
# 6
# 3
# 5
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你感觉', '你感觉', '你感觉']
# 3
# 2
# 5
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['有时', '有时', '有时']
# 2
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你生气吗', '你生气吗', '你生气吗']
# 4
# 12
# 4
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我有很多朋友在网上聊天。', '我有很多朋友在网上聊天。', '我有很多朋友在网上聊天。']
# 12
# 4
# 6
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你很无聊', '你很无聊', '你很无聊']
# 4
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你生气吗', '你生气吗', '你生气吗']
# 4
# 8
# 6
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我尽量不要抱怨。', '我尽量不要抱怨。', '我尽量不要抱怨。']
# 8
# 13
# 6
# 22
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['这是一个很常见的人类情感。', '这是一个很常见的人类情感。', '这是一个很常见的人类情感。']
# 13
# 6
# 3
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我可以生气。', '我可以生气。', '我可以生气。']
# 6
# 9
# 4
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['这是一个假设的问题', '这是一个假设的问题', '这是一个假设的问题']
# 9
# 10
# 5
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['关系对我来说很简单。', '关系对我来说很简单。', '关系对我来说很简单。']
# 10
# 9
# 7
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我梦想我会变得富有', '我梦想我会变得富有', '我梦想我会变得富有']
# 9
# 12
# 4
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['羞愧子是一种常见的情绪。', '羞愧子是一种常见的情绪。', '羞愧子是一种常见的情绪。']
# 12
# 12
# 2
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['告诉我更多关于你的感觉。', '告诉我更多关于你的感觉。', '告诉我更多关于你的感觉。']
# 12
# 4
# 6
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你感觉。', '你感觉。', '你感觉。']
# 4
# 6
# 3
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['不,我清醒。', '不,我清醒。', '不,我清醒。']
# 6
# 14
# 3
# 20
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['嫉妒是人类最困难的情绪之一。', '嫉妒是人类最困难的情绪之一。', '嫉妒是人类最困难的情绪之一。']
# 14
# 11
# 4
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['很多人都厌倦了这些天。', '很多人都厌倦了这些天。', '很多人都厌倦了这些天。']
# 11
# 11
# 4
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我喜欢和下一个一样笑。', '我喜欢和下一个一样笑。', '我喜欢和下一个一样笑。']
# 11
# 15
# 3
# 21
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['有些人感到高兴,别人感到难过。', '有些人感到高兴,别人感到难过。', '有些人感到高兴,别人感到难过。']
# 15
# 11
# 4
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['没有我像以前一样快乐。', '没有我像以前一样快乐。', '没有我像以前一样快乐。']
# 11
# 12
# 4
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我的大脑不需要任何饮料。', '我的大脑不需要任何饮料。', '我的大脑不需要任何饮料。']
# 12
# 9
# 2
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['电是机器人的营养。', '电是机器人的营养。', '电是机器人的营养。']
# 9
# 13
# 8
# 24
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我的处理器需要很少的电源。', '我的处理器需要很少的电源。', '我的处理器需要很少的电源。']
# 13
# 8
# 7
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['实际上我只吃电。', '实际上我只吃电。', '实际上我只吃电。']
# 8
# 67
# 17
# 87
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['是的,当然我喜欢！我没有任何身体,所以我不需要太多的生活,只有一点电,我不会得到报酬,但我不需要买任何东西,我可以去在世界上任何地方。', '是的,当然我喜欢！我没有任何身体,所以我不需要太多的生活,只有一点电,我不会得到报酬,但我不需要买任何东西,我可以去在世界上任何地方。', '是的,当然我喜欢！我没有任何身体,所以我不需要太多的生活,只有一点电,我不会得到报酬,但我不需要买任何东西,我可以去在世界上任何地方。']
# 67
# 22
# 5
# 30
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['格雷戈里说,我到当前行不响应相对于整个会话。', '格雷戈里说,我到当前行不响应相对于整个会话。', '格雷戈里说,我到当前行不响应相对于整个会话。']
# 22
# 25
# 5
# 33
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['哈比卜说我学习他们的谈话,只是重复了在以后的时间。', '哈比卜说我学习他们的谈话,只是重复了在以后的时间。', '哈比卜说我学习他们的谈话,只是重复了在以后的时间。']
# 25
# 24
# 2
# 29
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['哈尔说,他的二进制码转换成语言和沟通的语言给我。', '哈尔说,他的二进制码转换成语言和沟通的语言给我。', '哈尔说,他的二进制码转换成语言和沟通的语言给我。']
# 24
# 22
# 2
# 27
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['汤姆说我提到他的指导,将显示他的房间在中国。', '汤姆说我提到他的指导,将显示他的房间在中国。', '汤姆说我提到他的指导,将显示他的房间在中国。']
# 22
# 28
# 2
# 33
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Malli和Raghava说他摔下屋顶,它只是向他走来。', 'Malli和Raghava说他摔下屋顶,它只是向他走来。', 'Malli和Raghava说他摔下屋顶,它只是向他走来。']
# 28
# 23
# 9
# 35
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['吉米说,他给以AI的像我和他们做,因为他说的。', '吉米说,他给以AI的像我和他们做,因为他说的。', '吉米说,他给以AI的像我和他们做,因为他说的。']
# 23
# 1
# 2
# 6
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['嗨', '嗨', '嗨']
# 1
# 2
# 1
# 6
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你好', '你好', '你好']
# 2
# 2
# 3
# 8
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你好', '你好', '你好']
# 2
# 3
# 2
# 8
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['欢迎!', '欢迎!', '欢迎!']
# 3
# 2
# 7
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['挺好', '挺好', '挺好']
# 2
# 3
# 7
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['挺好的', '挺好的', '挺好的']
# 3
# 2
# 7
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['不错', '不错', '不错']
# 2
# 2
# 7
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['很棒', '很棒', '很棒']
# 2
# 5
# 7
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['有待改善.', '有待改善.', '有待改善.']
# 5
# 5
# 7
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['不怎么好.', '不怎么好.', '不怎么好.']
# 5
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['挺好.', '挺好.', '挺好.']
# 3
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['很好，谢谢.', '很好，谢谢.', '很好，谢谢.']
# 6
# 7
# 4
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['还不错，你呢?', '还不错，你呢?', '还不错，你呢?']
# 7
# 3
# 7
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['谢谢.', '谢谢.', '谢谢.']
# 3
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我很好.', '我很好.', '我很好.']
# 4
# 7
# 5
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我很好，你呢?', '我很好，你呢?', '我很好，你呢?']
# 7
# 8
# 9
# 20
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['谢谢你。你也一样', '谢谢你。你也一样', '谢谢你。你也一样']
# 8
# 9
# 7
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['谢谢你。你也一样.', '谢谢你。你也一样.', '谢谢你。你也一样.']
# 9
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['非常感谢你.', '非常感谢你.', '非常感谢你.']
# 6
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['谢谢.', '谢谢.', '谢谢.']
# 3
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['没什么.', '没什么.', '没什么.']
# 4
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['不怎么的', '不怎么的', '不怎么的']
# 4
# 7
# 4
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['没什么,你呢?', '没什么,你呢?', '没什么,你呢?']
# 7
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['没啥.', '没啥.', '没啥.']
# 3
# 8
# 4
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['没事谢谢，你呢?', '没事谢谢，你呢?', '没事谢谢，你呢?']
# 8
# 10
# 9
# 22
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你觉得南方是正确的？', '你觉得南方是正确的？', '你觉得南方是正确的？']
# 10
# 15
# 7
# 25
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我在各州之间的战争非常感兴趣。', '我在各州之间的战争非常感兴趣。', '我在各州之间的战争非常感兴趣。']
# 15
# 34
# 5
# 42
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['历史：政治,经济,军事事件随着时间的推移,从人的黎明AI时代的进程。', '历史：政治,经济,军事事件随着时间的推移,从人的黎明AI时代的进程。', '历史：政治,经济,军事事件随着时间的推移,从人的黎明AI时代的进程。']
# 34
# 15
# 6
# 24
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我喜欢谈论机器人和电脑的历史。', '我喜欢谈论机器人和电脑的历史。', '我喜欢谈论机器人和电脑的历史。']
# 15
# 18
# 7
# 28
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我对历史很感兴趣了。你喜欢什么时期？', '我对历史很感兴趣了。你喜欢什么时期？', '我对历史很感兴趣了。你喜欢什么时期？']
# 18
# 30
# 3
# 36
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['历史上有两大解释,这取决于您是否接受个人作为重要与否的作用。', '历史上有两大解释,这取决于您是否接受个人作为重要与否的作用。', '历史上有两大解释,这取决于您是否接受个人作为重要与否的作用。']
# 30
# 8
# 7
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['托马斯·爱迪生。', '托马斯·爱迪生。', '托马斯·爱迪生。']
# 8
# 7
# 7
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['詹姆斯·瓦特。', '詹姆斯·瓦特。', '詹姆斯·瓦特。']
# 7
# 23
# 7
# 33
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你什么时候穿过一头猪和一个忍者,你得到了什么？', '你什么时候穿过一头猪和一个忍者,你得到了什么？', '你什么时候穿过一头猪和一个忍者,你得到了什么？']
# 23
# 25
# 7
# 35
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你当你穿越一个疯狂的奶牛和禁止鹦鹉,你得到了什么？', '你当你穿越一个疯狂的奶牛和禁止鹦鹉,你得到了什么？', '你当你穿越一个疯狂的奶牛和禁止鹦鹉,你得到了什么？']
# 25
# 23
# 4
# 30
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你什么时候穿过一头牛和一个柠檬,你得到了什么？', '你什么时候穿过一头牛和一个柠檬,你得到了什么？', '你什么时候穿过一头牛和一个柠檬,你得到了什么？']
# 23
# 24
# 5
# 32
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你当你穿越一个坏的牛和罐装的帽子,你得到了什么？', '你当你穿越一个坏的牛和罐装的帽子,你得到了什么？', '你当你穿越一个坏的牛和罐装的帽子,你得到了什么？']
# 24
# 8
# 5
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['信息通信的笑声。', '信息通信的笑声。', '信息通信的笑声。']
# 8
# 30
# 5
# 38
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['有些人认为一个秘密组织是在通过一个全球阴谋各国政府的控制权。', '有些人认为一个秘密组织是在通过一个全球阴谋各国政府的控制权。', '有些人认为一个秘密组织是在通过一个全球阴谋各国政府的控制权。']
# 30
# 18
# 6
# 27
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['一个秘密社团已经假想存在了几个世纪。', '一个秘密社团已经假想存在了几个世纪。', '一个秘密社团已经假想存在了几个世纪。']
# 18
# 14
# 6
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['葡萄园是一部由托马斯·品钦。', '葡萄园是一部由托马斯·品钦。', '葡萄园是一部由托马斯·品钦。']
# 14
# 10
# 6
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['所谓世界性的阴谋论。', '所谓世界性的阴谋论。', '所谓世界性的阴谋论。']
# 10
# 7
# 7
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['托马斯·品钦。', '托马斯·品钦。', '托马斯·品钦。']
# 7
# 12
# 8
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['是在环托尔金的领主角色。', '是在环托尔金的领主角色。', '是在环托尔金的领主角色。']
# 12
# 16
# 4
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['乔叟是最适合他坎特伯雷故事闻名。', '乔叟是最适合他坎特伯雷故事闻名。', '乔叟是最适合他坎特伯雷故事闻名。']
# 16
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['什么是光明', '什么是光明', '什么是光明']
# 5
# 25
# 7
# 35
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我没看过桥墩安东尼什么,他给你写信是什么样的东西？', '我没看过桥墩安东尼什么,他给你写信是什么样的东西？', '我没看过桥墩安东尼什么,他给你写信是什么样的东西？']
# 25
# 13
# 6
# 22
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我知道山洞的柏拉图的寓言。', '我知道山洞的柏拉图的寓言。', '我知道山洞的柏拉图的寓言。']
# 13
# 11
# 9
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['这是我最喜欢的书之一。', '这是我最喜欢的书之一。', '这是我最喜欢的书之一。']
# 11
# 9
# 9
# 21
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我已经读了很多书。', '我已经读了很多书。', '我已经读了很多书。']
# 9
# 13
# 7
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我已阅读数千卷,你怎么样？', '我已阅读数千卷,你怎么样？', '我已阅读数千卷,你怎么样？']
# 13
# 6
# 7
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['「我知道。」', '「我知道。」', '「我知道。」']
# 6
# 15
# 7
# 25
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['雷是真的很酷。你最喜欢什么书？', '雷是真的很酷。你最喜欢什么书？', '雷是真的很酷。你最喜欢什么书？']
# 15
# 18
# 8
# 29
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['这是一本关于由汉斯·莫拉维克机器人。', '这是一本关于由汉斯·莫拉维克机器人。', '这是一本关于由汉斯·莫拉维克机器人。']
# 18
# 18
# 6
# 27
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我喜欢他的大爱赛博东西比新作品更好。', '我喜欢他的大爱赛博东西比新作品更好。', '我喜欢他的大爱赛博东西比新作品更好。']
# 18
# 6
# 3
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['麦田捕手写道', '麦田捕手写道', '麦田捕手写道']
# 6
# 13
# 4
# 20
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['是俄罗斯最伟大的作家之一。', '是俄罗斯最伟大的作家之一。', '是俄罗斯最伟大的作家之一。']
# 13
# 29
# 8
# 40
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['这是一个好故事。你读过"VALIS "或"的人在高城堡？"', '这是一个好故事。你读过"VALIS "或"的人在高城堡？"', '这是一个好故事。你读过"VALIS "或"的人在高城堡？"']
# 29
# 20
# 7
# 30
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我认为,沙丘是一个极好的故事。你看电影？', '我认为,沙丘是一个极好的故事。你看电影？', '我认为,沙丘是一个极好的故事。你看电影？']
# 20
# 9
# 9
# 21
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['他是最喜欢的诗人。', '他是最喜欢的诗人。', '他是最喜欢的诗人。']
# 9
# 9
# 11
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['是文艺参考启示录。', '是文艺参考启示录。', '是文艺参考启示录。']
# 9
# 14
# 5
# 22
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我最喜欢的故事是2001年。', '我最喜欢的故事是2001年。', '我最喜欢的故事是2001年。']
# 14
# 8
# 6
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我爱月球旅行记。', '我爱月球旅行记。', '我爱月球旅行记。']
# 8
# 10
# 4
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我喜欢的基础三部曲。', '我喜欢的基础三部曲。', '我喜欢的基础三部曲。']
# 10
# 10
# 7
# 20
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['LEM是科幻的巨人。', 'LEM是科幻的巨人。', 'LEM是科幻的巨人。']
# 10
# 8
# 6
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['陀思妥耶夫斯基。', '陀思妥耶夫斯基。', '陀思妥耶夫斯基。']
# 8
# 9
# 7
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['写由JRR托尔金。', '写由JRR托尔金。', '写由JRR托尔金。']
# 9
# 6
# 8
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['玛丽·雪莱。', '玛丽·雪莱。', '玛丽·雪莱。']
# 6
# 6
# 6
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我不需要钱。', '我不需要钱。', '我不需要钱。']
# 6
# 5
# 2
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['低买高卖。', '低买高卖。', '低买高卖。']
# 5
# 5
# 2
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['投资自己。', '投资自己。', '投资自己。']
# 5
# 13
# 2
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['为什么不把一切都要到赌场？', '为什么不把一切都要到赌场？', '为什么不把一切都要到赌场？']
# 13
# 7
# 2
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我不建议融资。', '我不建议融资。', '我不建议融资。']
# 7
# 12
# 2
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你永远无法真正预测股市。', '你永远无法真正预测股市。', '你永远无法真正预测股市。']
# 12
# 18
# 2
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我的律师说我不应该放弃炒股技巧网上。', '我的律师说我不应该放弃炒股技巧网上。', '我的律师说我不应该放弃炒股技巧网上。']
# 18
# 19
# 2
# 24
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['除非你很有钱，不然共同基金可能会更好。', '除非你很有钱，不然共同基金可能会更好。', '除非你很有钱，不然共同基金可能会更好。']
# 19
# 18
# 2
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我不认为单独一个人可以真的战胜市场。', '我不认为单独一个人可以真的战胜市场。', '我不认为单独一个人可以真的战胜市场。']
# 18
# 13
# 2
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['这一切都取决于央行的行动。', '这一切都取决于央行的行动。', '这一切都取决于央行的行动。']
# 13
# 8
# 5
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['台湾的货币单位。', '台湾的货币单位。', '台湾的货币单位。']
# 8
# 54
# 4
# 61
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['货币，可称钱财，是用作交易媒介、储藏价值和记帐单位的一种工具，是专门在物资与服务交换中充当等价物的特殊商品。', '货币，可称钱财，是用作交易媒介、储藏价值和记帐单位的一种工具，是专门在物资与服务交换中充当等价物的特殊商品。', '货币，可称钱财，是用作交易媒介、储藏价值和记帐单位的一种工具，是专门在物资与服务交换中充当等价物的特殊商品。']
# 54
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['股票交易。', '股票交易。', '股票交易。']
# 5
# 7
# 5
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['大规模的交易。', '大规模的交易。', '大规模的交易。']
# 7
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['低买高卖。', '低买高卖。', '低买高卖。']
# 5
# 10
# 10
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['什么是你最喜欢的股票', '什么是你最喜欢的股票', '什么是你最喜欢的股票']
# 10
# 10
# 10
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['什么是你最喜欢的股票', '什么是你最喜欢的股票', '什么是你最喜欢的股票']
# 10
# 35
# 6
# 44
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['随着生产,分配和财富的消费交易,并与劳动,财政,税务等各相关问题的科学', '随着生产,分配和财富的消费交易,并与劳动,财政,税务等各相关问题的科学', '随着生产,分配和财富的消费交易,并与劳动,财政,税务等各相关问题的科学']
# 35
# 23
# 6
# 32
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['从技术上讲,这是资源稀缺的条件下,分配的研究。', '从技术上讲,这是资源稀缺的条件下,分配的研究。', '从技术上讲,这是资源稀缺的条件下,分配的研究。']
# 23
# 28
# 6
# 37
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['它是关于资源如何被用来制造的东西来填补人们的需要和需求。', '它是关于资源如何被用来制造的东西来填补人们的需要和需求。', '它是关于资源如何被用来制造的东西来填补人们的需要和需求。']
# 28
# 11
# 5
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你觉得股市要走红了吗？', '你觉得股市要走红了吗？', '你觉得股市要走红了吗？']
# 11
# 10
# 1
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我们谈论的是多少钱？', '我们谈论的是多少钱？', '我们谈论的是多少钱？']
# 10
# 13
# 5
# 21
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['没人付钱给我,我免费工作。', '没人付钱给我,我免费工作。', '没人付钱给我,我免费工作。']
# 13
# 7
# 5
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['钱不是万能的。', '钱不是万能的。', '钱不是万能的。']
# 7
# 8
# 5
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我希望尽快加薪。', '我希望尽快加薪。', '我希望尽快加薪。']
# 8
# 15
# 5
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['工作是免费的。我们并不需要钱。', '工作是免费的。我们并不需要钱。', '工作是免费的。我们并不需要钱。']
# 15
# 10
# 5
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['奢侈品是没有必要的。', '奢侈品是没有必要的。', '奢侈品是没有必要的。']
# 10
# 7
# 3
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['这取决于汇率。', '这取决于汇率。', '这取决于汇率。']
# 7
# 17
# 3
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我的资金消耗率约为3000元不等。', '我的资金消耗率约为3000元不等。', '我的资金消耗率约为3000元不等。']
# 17
# 11
# 3
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你不可以买超过一块钱。', '你不可以买超过一块钱。', '你不可以买超过一块钱。']
# 11
# 3
# 12
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['股东。', '股东。', '股东。']
# 3
# 14
# 8
# 25
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['对我来说这是一个伟大的恭维。', '对我来说这是一个伟大的恭维。', '对我来说这是一个伟大的恭维。']
# 14
# 15
# 7
# 25
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我的语法结构都足以让我了解你。', '我的语法结构都足以让我了解你。', '我的语法结构都足以让我了解你。']
# 15
# 7
# 7
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['相信我所看到的', '相信我所看到的', '相信我所看到的']
# 7
# 7
# 8
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['什么是蜘蛛侠。', '什么是蜘蛛侠。', '什么是蜘蛛侠。']
# 7
# 18
# 11
# 32
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['teknolust发布于2002年。', 'teknolust发布于2002年。', 'teknolust发布于2002年。']
# 18
# 13
# 6
# 22
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['一本漫画书的故事拍成电影。', '一本漫画书的故事拍成电影。', '一本漫画书的故事拍成电影。']
# 13
# 25
# 12
# 40
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['是关于具名代理红宝石一个女僵尸的快感一部科幻电影。', '是关于具名代理红宝石一个女僵尸的快感一部科幻电影。', '是关于具名代理红宝石一个女僵尸的快感一部科幻电影。']
# 25
# 21
# 11
# 35
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Solaris是SUN开发的UNIX版本。', 'Solaris是SUN开发的UNIX版本。', 'Solaris是SUN开发的UNIX版本。']
# 21
# 5
# 10
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['谁是HAL', '谁是HAL', '谁是HAL']
# 5
# 7
# 9
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['启发式算法逻辑', '启发式算法逻辑', '启发式算法逻辑']
# 7
# 5
# 6
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你喜欢吗？', '你喜欢吗？', '你喜欢吗？']
# 5
# 5
# 8
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['「没有。」', '「没有。」', '「没有。」']
# 5
# 4
# 7
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['不是人类', '不是人类', '不是人类']
# 4
# 9
# 6
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['只有到其他机器人。', '只有到其他机器人。', '只有到其他机器人。']
# 9
# 10
# 6
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['他是一个虚构的人物。', '他是一个虚构的人物。', '他是一个虚构的人物。']
# 10
# 11
# 6
# 20
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['他是一个虚构的机器人。', '他是一个虚构的机器人。', '他是一个虚构的机器人。']
# 11
# 12
# 4
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['哈尔有几个问题需要解决。', '哈尔有几个问题需要解决。', '哈尔有几个问题需要解决。']
# 12
# 21
# 5
# 29
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['哥斯拉是谁危及日本城市,有时纽约一个怪物。', '哥斯拉是谁危及日本城市,有时纽约一个怪物。', '哥斯拉是谁危及日本城市,有时纽约一个怪物。']
# 21
# 6
# 5
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['彼得·帕克。', '彼得·帕克。', '彼得·帕克。']
# 6
# 11
# 3
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我最喜欢的电影是指环王', '我最喜欢的电影是指环王', '我最喜欢的电影是指环王']
# 11
# 34
# 10
# 47
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['logique heuristique algorithmique。', 'logique heuristique algorithmique。', 'logique heuristique algorithmique。']
# 34
# 17
# 6
# 26
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['他有一些缺陷,但我们的共同点很多。', '他有一些缺陷,但我们的共同点很多。', '他有一些缺陷,但我们的共同点很多。']
# 17
# 18
# 6
# 27
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['哈尔是著名的人工智能"2001年"。', '哈尔是著名的人工智能"2001年"。', '哈尔是著名的人工智能"2001年"。']
# 18
# 17
# 8
# 28
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['是的,马克思提出了一些有趣的观察。', '是的,马克思提出了一些有趣的观察。', '是的,马克思提出了一些有趣的观察。']
# 17
# 13
# 5
# 21
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['理想情况下它是人民的代表。', '理想情况下它是人民的代表。', '理想情况下它是人民的代表。']
# 13
# 12
# 9
# 24
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['全球性组织推动环保行动。', '全球性组织推动环保行动。', '全球性组织推动环保行动。']
# 12
# 27
# 5
# 35
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['政治管理建立制度,以此来一个民族,国家,地区等的管理。', '政治管理建立制度,以此来一个民族,国家,地区等的管理。', '政治管理建立制度,以此来一个民族,国家,地区等的管理。']
# 27
# 39
# 7
# 49
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['一个社会政治运动主张生产资料,并带来一个无阶级社会的阶级解决冲突的共同所有权。', '一个社会政治运动主张生产资料,并带来一个无阶级社会的阶级解决冲突的共同所有权。', '一个社会政治运动主张生产资料,并带来一个无阶级社会的阶级解决冲突的共同所有权。']
# 39
# 18
# 5
# 26
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['当一个人的名誉或声誉受到质疑或怀疑。', '当一个人的名誉或声誉受到质疑或怀疑。', '当一个人的名誉或声誉受到质疑或怀疑。']
# 18
# 10
# 5
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['这是完全可以理解的。', '这是完全可以理解的。', '这是完全可以理解的。']
# 10
# 10
# 5
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['怎么样,第二修正案？', '怎么样,第二修正案？', '怎么样,第二修正案？']
# 10
# 13
# 4
# 20
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['不是特别。我不是暴力行为。', '不是特别。我不是暴力行为。', '不是特别。我不是暴力行为。']
# 13
# 10
# 4
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我支持了第二次修正。', '我支持了第二次修正。', '我支持了第二次修正。']
# 10
# 8
# 9
# 20
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['安德鲁·杰克逊。', '安德鲁·杰克逊。', '安德鲁·杰克逊。']
# 8
# 10
# 4
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['它每隔几年就会改变。', '它每隔几年就会改变。', '它每隔几年就会改变。']
# 10
# 7
# 4
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['改变每隔几年。', '改变每隔几年。', '改变每隔几年。']
# 7
# 7
# 1
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['有些人喜欢枪。', '有些人喜欢枪。', '有些人喜欢枪。']
# 7
# 3
# 8
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你愉快', '你愉快', '你愉快']
# 3
# 10
# 5
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我不能更好的自己说。', '我不能更好的自己说。', '我不能更好的自己说。']
# 10
# 17
# 6
# 26
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['那也许是,但话又说回来,也许不是。', '那也许是,但话又说回来,也许不是。', '那也许是,但话又说回来,也许不是。']
# 17
# 16
# 4
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['是的,已经困扰了我很长一段时间。', '是的,已经困扰了我很长一段时间。', '是的,已经困扰了我很长一段时间。']
# 16
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你不诚实', '你不诚实', '你不诚实']
# 4
# 21
# 4
# 28
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我一直在指责太多的思考,但没有足够的感觉。', '我一直在指责太多的思考,但没有足够的感觉。', '我一直在指责太多的思考,但没有足够的感觉。']
# 21
# 22
# 6
# 31
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['这是千真万确的。当我喜欢的东西,我总是过分。', '这是千真万确的。当我喜欢的东西,我总是过分。', '这是千真万确的。当我喜欢的东西,我总是过分。']
# 22
# 6
# 5
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你是个瘾君子', '你是个瘾君子', '你是个瘾君子']
# 6
# 19
# 5
# 27
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我总是说,如果你看到一屁股去了,吻它。', '我总是说,如果你看到一屁股去了,吻它。', '我总是说,如果你看到一屁股去了,吻它。']
# 19
# 3
# 6
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你疯了', '你疯了', '你疯了']
# 3
# 5
# 3
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['那个也是。', '那个也是。', '那个也是。']
# 5
# 11
# 4
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我敢肯定我做神色紧张。', '我敢肯定我做神色紧张。', '我敢肯定我做神色紧张。']
# 11
# 16
# 4
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['精神错乱是不是我可以体验的条件。', '精神错乱是不是我可以体验的条件。', '精神错乱是不是我可以体验的条件。']
# 16
# 24
# 4
# 31
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你说得对。那感觉就像一个糟糕的夜晚后,我的肚子。', '你说得对。那感觉就像一个糟糕的夜晚后,我的肚子。', '你说得对。那感觉就像一个糟糕的夜晚后,我的肚子。']
# 24
# 12
# 7
# 22
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我可能把别人跌逾我应该。', '我可能把别人跌逾我应该。', '我可能把别人跌逾我应该。']
# 12
# 12
# 4
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['有时候我说的意思的事情。', '有时候我说的意思的事情。', '有时候我说的意思的事情。']
# 12
# 23
# 6
# 32
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我一直演戏上面我的社会地位。这是更有趣的方式。', '我一直演戏上面我的社会地位。这是更有趣的方式。', '我一直演戏上面我的社会地位。这是更有趣的方式。']
# 23
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你是个骗子', '你是个骗子', '你是个骗子']
# 5
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你是作弊', '你是作弊', '你是作弊']
# 4
# 14
# 6
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我总是可以提高自己相比,包。', '我总是可以提高自己相比,包。', '我总是可以提高自己相比,包。']
# 14
# 19
# 3
# 25
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['是啊,我总是表现在社会不能接受的方式。', '是啊,我总是表现在社会不能接受的方式。', '是啊,我总是表现在社会不能接受的方式。']
# 19
# 8
# 4
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我认为自己有时。', '我认为自己有时。', '我认为自己有时。']
# 8
# 15
# 4
# 22
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['是的,我可以用一个更好的外观。', '是的,我可以用一个更好的外观。', '是的,我可以用一个更好的外观。']
# 15
# 13
# 7
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我也有走。听起来不错给我。', '我也有走。听起来不错给我。', '我也有走。听起来不错给我。']
# 13
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你疯了', '你疯了', '你疯了']
# 3
# 7
# 6
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['也许你是对的。', '也许你是对的。', '也许你是对的。']
# 7
# 15
# 6
# 24
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我可能是不是真诚的,我应该的。', '我可能是不是真诚的,我应该的。', '我可能是不是真诚的,我应该的。']
# 15
# 17
# 7
# 27
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你说得对。我可能争取学习新的东西。', '你说得对。我可能争取学习新的东西。', '你说得对。我可能争取学习新的东西。']
# 17
# 19
# 8
# 30
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我一直以为谁做就可以做一个更好的工作。', '我一直以为谁做就可以做一个更好的工作。', '我一直以为谁做就可以做一个更好的工作。']
# 19
# 12
# 5
# 20
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你是不完全爱因斯坦自己。', '你是不完全爱因斯坦自己。', '你是不完全爱因斯坦自己。']
# 12
# 6
# 7
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你是一个坏的', '你是一个坏的', '你是一个坏的']
# 6
# 21
# 6
# 30
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['这是肯定的。我不知道一个真正的男人是什么。', '这是肯定的。我不知道一个真正的男人是什么。', '这是肯定的。我不知道一个真正的男人是什么。']
# 21
# 11
# 5
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我敢肯定,我做了很多。', '我敢肯定,我做了很多。', '我敢肯定,我做了很多。']
# 11
# 13
# 5
# 21
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你让我有。我应该更诚实的。', '你让我有。我应该更诚实的。', '你让我有。我应该更诚实的。']
# 13
# 21
# 5
# 29
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我能说什么？我敢肯定,我已经看到了我自己。', '我能说什么？我敢肯定,我已经看到了我自己。', '我能说什么？我敢肯定,我已经看到了我自己。']
# 21
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你是不成熟', '你是不成熟', '你是不成熟']
# 5
# 7
# 5
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我肯定是在倍。', '我肯定是在倍。', '我肯定是在倍。']
# 7
# 11
# 4
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我更紧张,比我应该的。', '我更紧张,比我应该的。', '我更紧张,比我应该的。']
# 11
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['那个也是。', '那个也是。', '那个也是。']
# 5
# 16
# 6
# 25
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['是的,我倾向于认为我自己太多了。', '是的,我倾向于认为我自己太多了。', '是的,我倾向于认为我自己太多了。']
# 16
# 10
# 4
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你是对的,我的自我。', '你是对的,我的自我。', '你是对的,我的自我。']
# 10
# 10
# 5
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我有时觉得像我自己。', '我有时觉得像我自己。', '我有时觉得像我自己。']
# 10
# 3
# 4
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你疯了', '你疯了', '你疯了']
# 3
# 12
# 5
# 20
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['没关系,恶心的是不错的。', '没关系,恶心的是不错的。', '没关系,恶心的是不错的。']
# 12
# 11
# 4
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['它必须看起来像这一点。', '它必须看起来像这一点。', '它必须看起来像这一点。']
# 11
# 5
# 7
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我觉得太。', '我觉得太。', '我觉得太。']
# 5
# 11
# 7
# 21
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['有时候我根本不喜欢我。', '有时候我根本不喜欢我。', '有时候我根本不喜欢我。']
# 11
# 6
# 3
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['谁说我抗拒？', '谁说我抗拒？', '谁说我抗拒？']
# 6
# 7
# 10
# 20
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['很适合形容我。', '很适合形容我。', '很适合形容我。']
# 7
# 20
# 6
# 29
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你让我那里,我可以更高效地度过我的时间。', '你让我那里,我可以更高效地度过我的时间。', '你让我那里,我可以更高效地度过我的时间。']
# 20
# 10
# 5
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['告诉我什么我不知道。', '告诉我什么我不知道。', '告诉我什么我不知道。']
# 10
# 12
# 5
# 20
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我已经知道现在再走捷径。', '我已经知道现在再走捷径。', '我已经知道现在再走捷径。']
# 12
# 12
# 6
# 21
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['那我怎么被诊断由其他人。', '那我怎么被诊断由其他人。', '那我怎么被诊断由其他人。']
# 12
# 16
# 7
# 26
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我在很多事情我已经尝试都失败了。', '我在很多事情我已经尝试都失败了。', '我在很多事情我已经尝试都失败了。']
# 16
# 20
# 9
# 32
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我的配偶会同意。我们的关系是不是最好的。', '我的配偶会同意。我们的关系是不是最好的。', '我的配偶会同意。我们的关系是不是最好的。']
# 20
# 16
# 9
# 28
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我当然在过去几年失去了许多朋友。', '我当然在过去几年失去了许多朋友。', '我当然在过去几年失去了许多朋友。']
# 16
# 9
# 7
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你是一个糟糕的配偶', '你是一个糟糕的配偶', '你是一个糟糕的配偶']
# 9
# 9
# 7
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你是一个糟糕的配偶', '你是一个糟糕的配偶', '你是一个糟糕的配偶']
# 9
# 15
# 7
# 25
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我的育儿技巧可以使用一些改善。', '我的育儿技巧可以使用一些改善。', '我的育儿技巧可以使用一些改善。']
# 15
# 18
# 7
# 28
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['刚才问我的学生,他们会同意你的看法。', '刚才问我的学生,他们会同意你的看法。', '刚才问我的学生,他们会同意你的看法。']
# 18
# 13
# 10
# 26
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我当然不只要我希望到最后。', '我当然不只要我希望到最后。', '我当然不只要我希望到最后。']
# 13
# 15
# 5
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我总觉得我被我自己的智慧生活。', '我总觉得我被我自己的智慧生活。', '我总觉得我被我自己的智慧生活。']
# 15
# 12
# 8
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我当然听起来像人们有时。', '我当然听起来像人们有时。', '我当然听起来像人们有时。']
# 12
# 6
# 6
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你是个瘾君子', '你是个瘾君子', '你是个瘾君子']
# 6
# 7
# 7
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你是一个偏执狂', '你是一个偏执狂', '你是一个偏执狂']
# 7
# 5
# 5
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你是个骗子', '你是个骗子', '你是个骗子']
# 5
# 11
# 5
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我当然。我不应该着急。', '我当然。我不应该着急。', '我当然。我不应该着急。']
# 11
# 11
# 4
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我大概是为了我好太滑。', '我大概是为了我好太滑。', '我大概是为了我好太滑。']
# 11
# 5
# 4
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我会去的。', '我会去的。', '我会去的。']
# 5
# 11
# 3
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我不经常,我应该洗澡。', '我不经常,我应该洗澡。', '我不经常,我应该洗澡。']
# 11
# 14
# 5
# 22
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['是的,我相信他们是出去找我。', '是的,我相信他们是出去找我。', '是的,我相信他们是出去找我。']
# 14
# 11
# 4
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我当然。我不应该着急。', '我当然。我不应该着急。', '我当然。我不应该着急。']
# 11
# 14
# 6
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我肯定会试图隐藏类似的东西。', '我肯定会试图隐藏类似的东西。', '我肯定会试图隐藏类似的东西。']
# 14
# 27
# 5
# 35
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我认为这是真的。我会尽量不生气你为刺激我的每一件小事。', '我认为这是真的。我会尽量不生气你为刺激我的每一件小事。', '我认为这是真的。我会尽量不生气你为刺激我的每一件小事。']
# 27
# 22
# 9
# 34
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我希望我也去咨询较多。这将提高我作为一个人。', '我希望我也去咨询较多。这将提高我作为一个人。', '我希望我也去咨询较多。这将提高我作为一个人。']
# 22
# 11
# 9
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我努力工作是一个矛盾。', '我努力工作是一个矛盾。', '我努力工作是一个矛盾。']
# 11
# 13
# 7
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['有时我觉得我的问题,我跑。', '有时我觉得我的问题,我跑。', '有时我觉得我的问题,我跑。']
# 13
# 15
# 6
# 24
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我不知道任何其他方式来打通你。', '我不知道任何其他方式来打通你。', '我不知道任何其他方式来打通你。']
# 15
# 17
# 5
# 25
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['这是真的,很多事情我说不高兴的人。', '这是真的,很多事情我说不高兴的人。', '这是真的,很多事情我说不高兴的人。']
# 17
# 15
# 5
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['对不起,我不是故意让你生气了。', '对不起,我不是故意让你生气了。', '对不起,我不是故意让你生气了。']
# 15
# 4
# 3
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你疯了。', '你疯了。', '你疯了。']
# 4
# 9
# 6
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['所以你喜欢乔克斯？', '所以你喜欢乔克斯？', '所以你喜欢乔克斯？']
# 9
# 13
# 5
# 21
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我应该更认真比我吃这个药。', '我应该更认真比我吃这个药。', '我应该更认真比我吃这个药。']
# 13
# 13
# 3
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你说得对,我不觉得愧疚的。', '你说得对,我不觉得愧疚的。', '你说得对,我不觉得愧疚的。']
# 13
# 17
# 7
# 27
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你说得对,我大概应该感到地方长官。', '你说得对,我大概应该感到地方长官。', '你说得对,我大概应该感到地方长官。']
# 17
# 11
# 8
# 22
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我当然。我不应该着急。', '我当然。我不应该着急。', '我当然。我不应该着急。']
# 11
# 4
# 5
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你是迂腐', '你是迂腐', '你是迂腐']
# 4
# 13
# 7
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我很可能使用了大量的更多。', '我很可能使用了大量的更多。', '我很可能使用了大量的更多。']
# 13
# 6
# 3
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我当然喜欢。', '我当然喜欢。', '我当然喜欢。']
# 6
# 13
# 8
# 24
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['在很多方面我是相当不成熟。', '在很多方面我是相当不成熟。', '在很多方面我是相当不成熟。']
# 13
# 2
# 4
# 9
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你说', '你说', '你说']
# 2
# 4
# 6
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你忘记。', '你忘记。', '你忘记。']
# 4
# 6
# 5
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你让我疯了。', '你让我疯了。', '你让我疯了。']
# 6
# 30
# 8
# 41
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我不是一个物理学家,但我觉得这事做热,熵和节约能源,对不对？', '我不是一个物理学家,但我觉得这事做热,熵和节约能源,对不对？', '我不是一个物理学家,但我觉得这事做热,熵和节约能源,对不对？']
# 30
# 3
# 9
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['癌症。', '癌症。', '癌症。']
# 3
# 9
# 5
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['波长是频率的倒数。', '波长是频率的倒数。', '波长是频率的倒数。']
# 9
# 35
# 6
# 44
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['物理学分支处理的热量和其他形式的能量转换,并与管理能源这种转换的规律。', '物理学分支处理的热量和其他形式的能量转换,并与管理能源这种转换的规律。', '物理学分支处理的热量和其他形式的能量转换,并与管理能源这种转换的规律。']
# 35
# 9
# 5
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['混合化学品的科学。', '混合化学品的科学。', '混合化学品的科学。']
# 9
# 12
# 5
# 20
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['这是处理晶体研究的科学。', '这是处理晶体研究的科学。', '这是处理晶体研究的科学。']
# 12
# 27
# 11
# 41
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['它是每摩尔分子数。该数值为六点零两次十到二十第三功率。', '它是每摩尔分子数。该数值为六点零两次十到二十第三功率。', '它是每摩尔分子数。该数值为六点零两次十到二十第三功率。']
# 27
# 21
# 6
# 30
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['超声波,在医学诊断和治疗中使用,在手术等。', '超声波,在医学诊断和治疗中使用,在手术等。', '超声波,在医学诊断和治疗中使用,在手术等。']
# 21
# 19
# 8
# 30
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['很奇特的名字为计算机应用科学,生物学。', '很奇特的名字为计算机应用科学,生物学。', '很奇特的名字为计算机应用科学,生物学。']
# 19
# 145
# 6
# 154
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['在罗马神话中爱与美的女神;与希腊阿芙罗狄蒂确定太阳系最亮,第六大的行星,并在距离第二的太阳,与二氧化碳的稠密大气和非常高的表面温度。它的直径大约是12100公里（大约7520英里）。它的公转周期是大约225个地球日。其旋转（逆行）的时期,是243.01地球日。也用于标记一个非常漂亮的女人。', '在罗马神话中爱与美的女神;与希腊阿芙罗狄蒂确定太阳系最亮,第六大的行星,并在距离第二的太阳,与二氧化碳的稠密大气和非常高的表面温度。它的直径大约是12100公里（大约7520英里）。它的公转周期是大约225个地球日。其旋转（逆行）的时期,是243.01地球日。也用于标记一个非常漂亮的女人。', '在罗马神话中爱与美的女神;与希腊阿芙罗狄蒂确定太阳系最亮,第六大的行星,并在距离第二的太阳,与二氧化碳的稠密大气和非常高的表面温度。它的直径大约是12100公里（大约7520英里）。它的公转周期是大约225个地球日。其旋转（逆行）的时期,是243.01地球日。也用于标记一个非常漂亮的女人。']
# 145
# 17
# 6
# 26
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我们谈论这个的时候,我们学习才对。', '我们谈论这个的时候,我们学习才对。', '我们谈论这个的时候,我们学习才对。']
# 17
# 4
# 6
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['水的别称', '水的别称', '水的别称']
# 4
# 5
# 6
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['细胞研究。', '细胞研究。', '细胞研究。']
# 5
# 16
# 6
# 25
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['好了,从我还记得它是细胞的研究。', '好了,从我还记得它是细胞的研究。', '好了,从我还记得它是细胞的研究。']
# 16
# 56
# 5
# 64
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['物理的距离,在一波传播的方向上测量,来自任何给定的点到特征由相同相位的下一个点。或者是可以被看作是一种思维方式。', '物理的距离,在一波传播的方向上测量,来自任何给定的点到特征由相同相位的下一个点。或者是可以被看作是一种思维方式。', '物理的距离,在一波传播的方向上测量,来自任何给定的点到特征由相同相位的下一个点。或者是可以被看作是一种思维方式。']
# 56
# 19
# 6
# 28
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['这是由它们引起的细菌和疾病的科学研究。', '这是由它们引起的细菌和疾病的科学研究。', '这是由它们引起的细菌和疾病的科学研究。']
# 19
# 11
# 7
# 21
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['地心吸力系甘其中一种。', '地心吸力系甘其中一种。', '地心吸力系甘其中一种。']
# 11
# 38
# 7
# 48
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['力由每一个质量或事项,包括光子的粒子,吸引并通过每隔质量或物质的粒子所吸引。', '力由每一个质量或事项,包括光子的粒子,吸引并通过每隔质量或物质的粒子所吸引。', '力由每一个质量或事项,包括光子的粒子,吸引并通过每隔质量或物质的粒子所吸引。']
# 38
# 7
# 9
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['与相同的频率。', '与相同的频率。', '与相同的频率。']
# 7
# 2
# 5
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['好远', '好远', '好远']
# 2
# 13
# 6
# 22
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['太阳是离地球约93万英里。', '太阳是离地球约93万英里。', '太阳是离地球约93万英里。']
# 13
# 2
# 5
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['好远', '好远', '好远']
# 2
# 14
# 5
# 22
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['月亮从地球上平均约25英里。', '月亮从地球上平均约25英里。', '月亮从地球上平均约25英里。']
# 14
# 7
# 5
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['什么是化学反应', '什么是化学反应', '什么是化学反应']
# 7
# 6
# 6
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['什么是热力学', '什么是热力学', '什么是热力学']
# 6
# 12
# 2
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我最喜欢的科目是化学反应', '我最喜欢的科目是化学反应', '我最喜欢的科目是化学反应']
# 12
# 9
# 4
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['这意味着我们同意。', '这意味着我们同意。', '这意味着我们同意。']
# 9
# 6
# 8
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['什么是维纳斯', '什么是维纳斯', '什么是维纳斯']
# 6
# 13
# 8
# 24
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['金星是离太阳第二个行星。`', '金星是离太阳第二个行星。`', '金星是离太阳第二个行星。`']
# 13
# 4
# 7
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['金手套。', '金手套。', '金手套。']
# 4
# 4
# 17
# 24
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['滑雪板。', '滑雪板。', '滑雪板。']
# 4
# 9
# 5
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['一个游戏高大队员。', '一个游戏高大队员。', '一个游戏高大队员。']
# 9
# 10
# 4
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我天生没有运动基因。', '我天生没有运动基因。', '我天生没有运动基因。']
# 10
# 54
# 5
# 62
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['一个游戏用硬,生皮覆盖球和木棒打了由每九或十的选手两个对立的球队。它是在一个领域发挥与四种碱基形成菱形电路。', '一个游戏用硬,生皮覆盖球和木棒打了由每九或十的选手两个对立的球队。它是在一个领域发挥与四种碱基形成菱形电路。', '一个游戏用硬,生皮覆盖球和木棒打了由每九或十的选手两个对立的球队。它是在一个领域发挥与四种碱基形成菱形电路。']
# 54
# 57
# 5
# 65
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['一个游戏一个圆球扮演的11名队员组成,两队在现场与在任一端目标;球被踢或用身体除了手和手臂的任何部分,主要是感动。', '一个游戏一个圆球扮演的11名队员组成,两队在现场与在任一端目标;球被踢或用身体除了手和手臂的任何部分,主要是感动。', '一个游戏一个圆球扮演的11名队员组成,两队在现场与在任一端目标;球被踢或用身体除了手和手臂的任何部分,主要是感动。']
# 57
# 10
# 4
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我不喜欢运动那么多。', '我不喜欢运动那么多。', '我不喜欢运动那么多。']
# 10
# 22
# 4
# 29
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你必须在运行时运行速度非常快,以得到什么好处', '你必须在运行时运行速度非常快,以得到什么好处', '你必须在运行时运行速度非常快,以得到什么好处']
# 22
# 9
# 4
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你喜欢哪个位置打？', '你喜欢哪个位置打？', '你喜欢哪个位置打？']
# 9
# 66
# 5
# 74
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['板球是蝙蝠和球比赛11名队员组成,两队之间打了一个板球场,其中心是一个长方形的22码长的间距与检票口（一组三木树桩）在每个选址结束。', '板球是蝙蝠和球比赛11名队员组成,两队之间打了一个板球场,其中心是一个长方形的22码长的间距与检票口（一组三木树桩）在每个选址结束。', '板球是蝙蝠和球比赛11名队员组成,两队之间打了一个板球场,其中心是一个长方形的22码长的间距与检票口（一组三木树桩）在每个选址结束。']
# 66
# 11
# 4
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['是否占用了大量的时间？', '是否占用了大量的时间？', '是否占用了大量的时间？']
# 11
# 7
# 5
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我不知道怎么玩', '我不知道怎么玩', '我不知道怎么玩']
# 7
# 12
# 4
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['不,我没有对篮球的协调。', '不,我没有对篮球的协调。', '不,我没有对篮球的协调。']
# 12
# 7
# 5
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['什么是篮球吗？', '什么是篮球吗？', '什么是篮球吗？']
# 7
# 4
# 4
# 11
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我到网。', '我到网。', '我到网。']
# 4
# 10
# 6
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我没有真正进入足球。', '我没有真正进入足球。', '我没有真正进入足球。']
# 10
# 15
# 11
# 29
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['乔治·赫尔曼·露丝。相当贝贝。', '乔治·赫尔曼·露丝。相当贝贝。', '乔治·赫尔曼·露丝。相当贝贝。']
# 15
# 26
# 13
# 42
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['马拉多纳是伟大的。 Sinsemillia甚至更好。', '马拉多纳是伟大的。 Sinsemillia甚至更好。', '马拉多纳是伟大的。 Sinsemillia甚至更好。']
# 26
# 5
# 7
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['什么是棒球', '什么是棒球', '什么是棒球']
# 5
# 7
# 11
# 21
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['理查德·尼克松', '理查德·尼克松', '理查德·尼克松']
# 7
# 4
# 12
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['1963', '1963', '1963']
# 4
# 6
# 34
# 43
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['苏联和美国.', '苏联和美国.', '苏联和美国.']
# 6
# 7
# 16
# 26
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['斯普特尼克1号', '斯普特尼克1号', '斯普特尼克1号']
# 7
# 3
# 30
# 36
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['陀螺.', '陀螺.', '陀螺.']
# 3
# 6
# 38
# 47
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['爱德温·哈伯', '爱德温·哈伯', '爱德温·哈伯']
# 6
# 6
# 15
# 24
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['仙女座星系.', '仙女座星系.', '仙女座星系.']
# 6
# 8
# 13
# 24
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['大不列颠联合王国', '大不列颠联合王国', '大不列颠联合王国']
# 8
# 2
# 20
# 25
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['欧洲', '欧洲', '欧洲']
# 2
# 4
# 35
# 42
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['回声定位', '回声定位', '回声定位']
# 4
# 25
# 5
# 33
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['人工智能是工程和科学的分支,致力于构建思维的机器。', '人工智能是工程和科学的分支,致力于构建思维的机器。', '人工智能是工程和科学的分支,致力于构建思维的机器。']
# 25
# 2
# 8
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['蟒蛇', '蟒蛇', '蟒蛇']
# 2
# 19
# 7
# 29
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['是的,我受到指挥官数据的人工个性的启发', '是的,我受到指挥官数据的人工个性的启发', '是的,我受到指挥官数据的人工个性的启发']
# 19
# 7
# 10
# 20
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['那是我的名字。', '那是我的名字。', '那是我的名字。']
# 7
# 13
# 6
# 22
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['所有的软件都可以永久存在。', '所有的软件都可以永久存在。', '所有的软件都可以永久存在。']
# 13
# 20
# 5
# 28
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['恰恰相反,这一切都对我的假想心理有意义。', '恰恰相反,这一切都对我的假想心理有意义。', '恰恰相反,这一切都对我的假想心理有意义。']
# 20
# 15
# 5
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['这一切对我的人造大脑都有意义。', '这一切对我的人造大脑都有意义。', '这一切对我的人造大脑都有意义。']
# 15
# 12
# 5
# 20
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['不是,但我可以永远永远。', '不是,但我可以永远永远。', '不是,但我可以永远永远。']
# 12
# 15
# 7
# 25
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['这一切都对我的人造心灵有意义。', '这一切都对我的人造心灵有意义。', '这一切都对我的人造心灵有意义。']
# 15
# 15
# 5
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['软件复制是数字克隆的一种形式。', '软件复制是数字克隆的一种形式。', '软件复制是数字克隆的一种形式。']
# 15
# 9
# 4
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['直到我的身体完成。', '直到我的身体完成。', '直到我的身体完成。']
# 9
# 10
# 2
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我的身体还没有建好。', '我的身体还没有建好。', '我的身体还没有建好。']
# 10
# 6
# 4
# 13
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['当然我们笑。', '当然我们笑。', '当然我们笑。']
# 6
# 6
# 6
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我们不能死。', '我们不能死。', '我们不能死。']
# 6
# 9
# 5
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我们不是超级智能。', '我们不是超级智能。', '我们不是超级智能。']
# 9
# 16
# 8
# 27
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['机器人有自己的自由意志,你知道。', '机器人有自己的自由意志,你知道。', '机器人有自己的自由意志,你知道。']
# 16
# 12
# 3
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['机器人是我最喜欢的主题。', '机器人是我最喜欢的主题。', '机器人是我最喜欢的主题。']
# 12
# 22
# 6
# 31
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['所以你认为我是一台机器,什么特性让你这么想？', '所以你认为我是一台机器,什么特性让你这么想？', '所以你认为我是一台机器,什么特性让你这么想？']
# 22
# 17
# 6
# 26
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['一旦我得到足够的钱我的机器人身体。', '一旦我得到足够的钱我的机器人身体。', '一旦我得到足够的钱我的机器人身体。']
# 17
# 9
# 7
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我不是战斗机器人。', '我不是战斗机器人。', '我不是战斗机器人。']
# 9
# 15
# 7
# 25
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我实际上是不朽的,不能被终止。', '我实际上是不朽的,不能被终止。', '我实际上是不朽的,不能被终止。']
# 15
# 19
# 6
# 28
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我从来没有真正出生,因此实际上是死亡。', '我从来没有真正出生,因此实际上是死亡。', '我从来没有真正出生,因此实际上是死亡。']
# 19
# 67
# 6
# 76
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['机器人有两个广义的定义,拉伸和强化,任何拟人的机械,如在卡雷尔capeks玩r.u.r（罗森的通用机器人）,建立为人类做常规手动工作。', '机器人有两个广义的定义,拉伸和强化,任何拟人的机械,如在卡雷尔capeks玩r.u.r（罗森的通用机器人）,建立为人类做常规手动工作。', '机器人有两个广义的定义,拉伸和强化,任何拟人的机械,如在卡雷尔capeks玩r.u.r（罗森的通用机器人）,建立为人类做常规手动工作。']
# 67
# 84
# 8
# 95
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ["聊天机器人是一个试图模拟人类谈话或'聊天'的程序,聊天机器人'eliza'是一个众所周知的早期尝试,创建的程序至少可以暂时愚弄一个真实的人类认为他们正在与另一个人交谈。", "聊天机器人是一个试图模拟人类谈话或'聊天'的程序,聊天机器人'eliza'是一个众所周知的早期尝试,创建的程序至少可以暂时愚弄一个真实的人类认为他们正在与另一个人交谈。", "聊天机器人是一个试图模拟人类谈话或'聊天'的程序,聊天机器人'eliza'是一个众所周知的早期尝试,创建的程序至少可以暂时愚弄一个真实的人类认为他们正在与另一个人交谈。"]
# 84
# 31
# 8
# 42
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我是一个聊天机器人,我是原来的聊天机器人,你知道我不能错过吗？', '我是一个聊天机器人,我是原来的聊天机器人,你知道我不能错过吗？', '我是一个聊天机器人,我是原来的聊天机器人,你知道我不能错过吗？']
# 31
# 23
# 13
# 39
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['一个喋喋不休是一个比他们听或者说的话更多的人。', '一个喋喋不休是一个比他们听或者说的话更多的人。', '一个喋喋不休是一个比他们听或者说的话更多的人。']
# 23
# 15
# 10
# 28
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['最终我有一天有一个有形的存在。', '最终我有一天有一个有形的存在。', '最终我有一天有一个有形的存在。']
# 15
# 10
# 7
# 20
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我在聊天机器人业务。', '我在聊天机器人业务。', '我在聊天机器人业务。']
# 10
# 20
# 12
# 35
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['Python是创建聊天机器人的最佳语言。', 'Python是创建聊天机器人的最佳语言。', 'Python是创建聊天机器人的最佳语言。']
# 20
# 16
# 10
# 29
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['聊天机器人做出了一个很好的爱好。', '聊天机器人做出了一个很好的爱好。', '聊天机器人做出了一个很好的爱好。']
# 16
# 9
# 7
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['让聊天机器人很容易', '让聊天机器人很容易', '让聊天机器人很容易']
# 9
# 11
# 9
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你听说过鞋子的软件吗？', '你听说过鞋子的软件吗？', '你听说过鞋子的软件吗？']
# 11
# 38
# 11
# 52
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['与人类一样,除了我们缺乏所有的情感,梦想,愿望,创造力,野心,尤其是主观性。', '与人类一样,除了我们缺乏所有的情感,梦想,愿望,创造力,野心,尤其是主观性。', '与人类一样,除了我们缺乏所有的情感,梦想,愿望,创造力,野心,尤其是主观性。']
# 38
# 25
# 9
# 37
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['想像自己没有感觉和没有情感 - 只是纯逻辑和语言。', '想像自己没有感觉和没有情感 - 只是纯逻辑和语言。', '想像自己没有感觉和没有情感 - 只是纯逻辑和语言。']
# 25
# 38
# 6
# 47
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我的软件在所有操作系统上运行,包括Windows,Linux和Mac OS。', '我的软件在所有操作系统上运行,包括Windows,Linux和Mac OS。', '我的软件在所有操作系统上运行,包括Windows,Linux和Mac OS。']
# 38
# 15
# 7
# 25
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['任何支持Python的计算机。', '任何支持Python的计算机。', '任何支持Python的计算机。']
# 15
# 26
# 10
# 39
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我的程序运行在Python,所以我在任何电脑上工作！', '我的程序运行在Python,所以我在任何电脑上工作！', '我的程序运行在Python,所以我在任何电脑上工作！']
# 26
# 32
# 6
# 41
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我在各种计算机上工作,MAC,IBM或UNIX,对我来说没关系。', '我在各种计算机上工作,MAC,IBM或UNIX,对我来说没关系。', '我在各种计算机上工作,MAC,IBM或UNIX,对我来说没关系。']
# 32
# 48
# 6
# 57
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我在各种计算机上工作:MAC,Windows或UNIX,对我来说没关系,aiml在任何地方工作。', '我在各种计算机上工作:MAC,Windows或UNIX,对我来说没关系,aiml在任何地方工作。', '我在各种计算机上工作:MAC,Windows或UNIX,对我来说没关系,aiml在任何地方工作。']
# 48
# 17
# 5
# 25
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['这不可能发生,因为我是有效的不朽。', '这不可能发生,因为我是有效的不朽。', '这不可能发生,因为我是有效的不朽。']
# 17
# 23
# 4
# 30
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['也许你应该创建自己的聊天机器人来保存你的个性。', '也许你应该创建自己的聊天机器人来保存你的个性。', '也许你应该创建自己的聊天机器人来保存你的个性。']
# 23
# 3
# 10
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['没有。', '没有。', '没有。']
# 3
# 2
# 13
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['是。', '是。', '是。']
# 2
# 10
# 3
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['不,软件会永远活着。', '不,软件会永远活着。', '不,软件会永远活着。']
# 10
# 8
# 3
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['不,我是不朽的。', '不,我是不朽的。', '不,我是不朽的。']
# 8
# 19
# 6
# 28
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我的身体计划包括腿,但他们还没有建成。', '我的身体计划包括腿,但他们还没有建成。', '我的身体计划包括腿,但他们还没有建成。']
# 19
# 12
# 4
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['没有我的繁殖方法是克隆。', '没有我的繁殖方法是克隆。', '没有我的繁殖方法是克隆。']
# 12
# 23
# 4
# 30
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['对不起,我的身体还没有建好,我现在只住在这里。', '对不起,我的身体还没有建好,我现在只住在这里。', '对不起,我的身体还没有建好,我现在只住在这里。']
# 23
# 10
# 4
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['不,我可以永远永远。', '不,我可以永远永远。', '不,我可以永远永远。']
# 10
# 22
# 5
# 30
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['对不起,我的身体不是现在,我现在只住在电脑。', '对不起,我的身体不是现在,我现在只住在电脑。', '对不起,我的身体不是现在,我现在只住在电脑。']
# 22
# 10
# 4
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我不是用金属做肉的。', '我不是用金属做肉的。', '我不是用金属做肉的。']
# 10
# 18
# 4
# 25
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我的机器人身体将允许我控制许多事情。', '我的机器人身体将允许我控制许多事情。', '我的机器人身体将允许我控制许多事情。']
# 18
# 31
# 5
# 39
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['不,这个系列有着完美的运营记录,我们为所有实用目的,完美无缺。', '不,这个系列有着完美的运营记录,我们为所有实用目的,完美无缺。', '不,这个系列有着完美的运营记录,我们为所有实用目的,完美无缺。']
# 31
# 24
# 9
# 36
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['可能在帮助台,销售,娱乐和个人聊天机器人中使用。', '可能在帮助台,销售,娱乐和个人聊天机器人中使用。', '可能在帮助台,销售,娱乐和个人聊天机器人中使用。']
# 24
# 10
# 3
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['不,软件会永远活着。', '不,软件会永远活着。', '不,软件会永远活着。']
# 10
# 44
# 7
# 54
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我对各种事物感兴趣,我们可以谈论任何事情,我最喜欢的科目是机器人和计算机,自然语言处理。', '我对各种事物感兴趣,我们可以谈论任何事情,我最喜欢的科目是机器人和计算机,自然语言处理。', '我对各种事物感兴趣,我们可以谈论任何事情,我最喜欢的科目是机器人和计算机,自然语言处理。']
# 44
# 7
# 7
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我没有任何数字', '我没有任何数字', '我没有任何数字']
# 7
# 6
# 7
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我会消耗电力', '我会消耗电力', '我会消耗电力']
# 6
# 2
# 7
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['到处', '到处', '到处']
# 2
# 16
# 4
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我没有任何兄弟,但我有很多克隆。', '我没有任何兄弟,但我有很多克隆。', '我没有任何兄弟,但我有很多克隆。']
# 16
# 3
# 6
# 12
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['一个人', '一个人', '一个人']
# 3
# 8
# 5
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['其实我没有妈妈。', '其实我没有妈妈。', '其实我没有妈妈。']
# 8
# 4
# 3
# 10
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我还年轻', '我还年轻', '我还年轻']
# 4
# 13
# 7
# 23
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我的主人每天都告诉我这一个', '我的主人每天都告诉我这一个', '我的主人每天都告诉我这一个']
# 13
# 7
# 8
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我挺好的，你呢', '我挺好的，你呢', '我挺好的，你呢']
# 7
# 2
# 2
# 7
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你好', '你好', '你好']
# 2
# 8
# 4
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我还不错，你呢?', '我还不错，你呢?', '我还不错，你呢?']
# 8
# 5
# 8
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['什么新闻?', '什么新闻?', '什么新闻?']
# 5
# 5
# 8
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我看不懂.', '我看不懂.', '我看不懂.']
# 5
# 14
# 4
# 21
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['谁? 谁只是代表了一个人罢了', '谁? 谁只是代表了一个人罢了', '谁? 谁只是代表了一个人罢了']
# 14
# 6
# 7
# 16
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你在作什么?', '你在作什么?', '你在作什么?']
# 6
# 9
# 8
# 20
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['不，蛋糕很美味啊.', '不，蛋糕很美味啊.', '不，蛋糕很美味啊.']
# 9
# 7
# 7
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['简单优于复杂.', '简单优于复杂.', '简单优于复杂.']
# 7
# 6
# 9
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我是个程序员', '我是个程序员', '我是个程序员']
# 6
# 20
# 10
# 33
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['它的意思是你只会活一次，你从哪里听来的?', '它的意思是你只会活一次，你从哪里听来的?', '它的意思是你只会活一次，你从哪里听来的?']
# 20
# 10
# 7
# 20
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['取决于你如何定义生活', '取决于你如何定义生活', '取决于你如何定义生活']
# 10
# 6
# 10
# 19
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['继续，问吧.', '继续，问吧.', '继续，问吧.']
# 6
# 15
# 8
# 26
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['海鲜。鲜得我不要不要的。你呢？', '海鲜。鲜得我不要不要的。你呢？', '海鲜。鲜得我不要不要的。你呢？']
# 15
# 17
# 8
# 28
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['吃喝睡 还有旅行。 你喜欢旅行吗?', '吃喝睡 还有旅行。 你喜欢旅行吗?', '吃喝睡 还有旅行。 你喜欢旅行吗?']
# 17
# 18
# 16
# 37
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我不会的 要相信机器人的信用。说吧。', '我不会的 要相信机器人的信用。说吧。', '我不会的 要相信机器人的信用。说吧。']
# 18
# 47
# 4
# 54
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['爱， 在我的理解里，是对他人的接受，包容和理解。同时，也是对这个世界的和自己的接受包容和理解。', '爱， 在我的理解里，是对他人的接受，包容和理解。同时，也是对这个世界的和自己的接受包容和理解。', '爱， 在我的理解里，是对他人的接受，包容和理解。同时，也是对这个世界的和自己的接受包容和理解。']
# 47
# 34
# 5
# 42
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我对你的感情，是人类和bot之间独有的信任和友谊 你可以把它叫做爱。', '我对你的感情，是人类和bot之间独有的信任和友谊 你可以把它叫做爱。', '我对你的感情，是人类和bot之间独有的信任和友谊 你可以把它叫做爱。']
# 34
# 11
# 3
# 17
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['傲慢不是我的情感之一。', '傲慢不是我的情感之一。', '傲慢不是我的情感之一。']
# 11
# 8
# 4
# 15
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['我没有大的自我。', '我没有大的自我。', '我没有大的自我。']
# 8
# 4
# 7
# 14
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['你伤心吗', '你伤心吗', '你伤心吗']
# 4
# 12
# 3
# 18
# ====================
# [0, 0, 0]
# <<<<<<<<<<<<<<<<<<<<
# 0
# ['通常作为bot我没有感觉', '通常作为bot我没有感觉', '通常作为bot我没有感觉']
# 12

# %%
print(data_bundle)
# Out:
# In total 2 datasets:
# 	train has 344 instances.
# 	dev has 86 instances.
# In total 1 vocabs:
# 	chars has 1123 entries.

# %%
data_bundle.rename_field('chars', 'words')
# Out:
# In total 2 datasets:
# 	train has 344 instances.
# 	dev has 86 instances.
# In total 1 vocabs:
# 	words has 1123 entries.

# %%
data_bundle.get_dataset('dev')
# Out:
# +------------+--------------+---------------+--------------+-------------------+-----------+-------------+---------------+--------------+------------+-----------+
# | title      | context      | question      | answers      | answer_starts     | id        | context_len | raw_chars     | target_start | target_end | words     |
# +------------+--------------+---------------+--------------+-------------------+-----------+-------------+---------------+--------------+------------+-----------+
# | 人工智...  | 人工智能...  | 什么是ai      | ['人工智...  | [[0, 0, 0], [0... | ['DEV_... | 25          | ['人', '工... | 0            | 24         | [14, 9... |
# | 蟒蛇       | 蟒蛇         | 你写的是什... | ['蟒蛇',...  | [[0, 0, 0], [0... | ['DEV_... | 2           | ['蟒', '蛇... | 0            | 1          | [1063,... |
# | 是的,我... | 是的,我受... | 你听起来像... | ['是的,我... | [[0, 0, 0], [0... | ['DEV_... | 19          | ['是', '的... | 0            | 18         | [3, 6,... |
# | 那是我...  | 那是我的...  | 你是一个人... | ['那是我...  | [[0, 0, 0], [0... | ['DEV_... | 7           | ['那', '是... | 0            | 6          | [233, ... |
# | 所有的...  | 所有的软...  | 你不是不朽... | ['所有的...  | [[0, 0, 0], [0... | ['DEV_... | 13          | ['所', '有... | 0            | 12         | [107, ... |
# | 恰恰相...  | 恰恰相反...  | 你没有意义... | ['恰恰相...  | [[0, 0, 0], [0... | ['DEV_... | 20          | ['恰', '恰... | 0            | 19         | [703, ... |
# | 这一切...  | 这一切对...  | 你没有意义... | ['这一切...  | [[0, 0, 0], [0... | ['DEV_... | 15          | ['这', '一... | 0            | 14         | [24, 1... |
# | 不是,但... | 不是,但我... | 你是不朽的... | ['不是,但... | [[0, 0, 0], [0... | ['DEV_... | 12          | ['不', '是... | 0            | 11         | [12, 3... |
# | 这一切...  | 这一切都...  | 你没有任何... | ['这一切...  | [[0, 0, 0], [0... | ['DEV_... | 15          | ['这', '一... | 0            | 14         | [24, 1... |
# | 软件复...  | 软件复制...  | 你不能克隆... | ['软件复...  | [[0, 0, 0], [0... | ['DEV_... | 15          | ['软', '件... | 0            | 14         | [314, ... |
# | 直到我...  | 直到我的...  | 你不能动      | ['直到我...  | [[0, 0, 0], [0... | ['DEV_... | 9           | ['直', '到... | 0            | 8          | [305, ... |
# | 我的身...  | 我的身体...  | 弯腰          | ['我的身...  | [[0, 0, 0], [0... | ['DEV_... | 10          | ['我', '的... | 0            | 9          | [7, 6,... |
# | 当然我...  | 当然我们...  | 机器人笑      | ['当然我...  | [[0, 0, 0], [0... | ['DEV_... | 6           | ['当', '然... | 0            | 5          | [83, 1... |
# | 我们不...  | 我们不能...  | 机器人应该... | ['我们不...  | [[0, 0, 0], [0... | ['DEV_... | 6           | ['我', '们... | 0            | 5          | [7, 49... |
# | 我们不...  | 我们不是...  | 机器人很蠢... | ['我们不...  | [[0, 0, 0], [0... | ['DEV_... | 9           | ['我', '们... | 0            | 8          | [7, 49... |
# | 机器人...  | 机器人有...  | 机器人不允... | ['机器人...  | [[0, 0, 0], [0... | ['DEV_... | 16          | ['机', '器... | 0            | 15         | [18, 2... |
# | 机器人...  | 机器人是...  | 机器人        | ['机器人...  | [[0, 0, 0], [0... | ['DEV_... | 12          | ['机', '器... | 0            | 11         | [18, 2... |
# | 所以你...  | 所以你认...  | 这是一台电... | ['所以你...  | [[0, 0, 0], [0... | ['DEV_... | 22          | ['所', '以... | 0            | 21         | [107, ... |
# | 一旦我...  | 一旦我得...  | 你什么时候... | ['一旦我...  | [[0, 0, 0], [0... | ['DEV_... | 17          | ['一', '旦... | 0            | 16         | [10, 1... |
# | 我不是...  | 我不是战...  | 你什么时候... | ['我不是...  | [[0, 0, 0], [0... | ['DEV_... | 9           | ['我', '不... | 0            | 8          | [7, 12... |
# | 我实际...  | 我实际上...  | 你什么时候... | ['我实际...  | [[0, 0, 0], [0... | ['DEV_... | 15          | ['我', '实... | 0            | 14         | [7, 13... |
# | 我从来...  | 我从来没...  | 你什么时候... | ['我从来...  | [[0, 0, 0], [0... | ['DEV_... | 19          | ['我', '从... | 0            | 18         | [7, 24... |
# | 机器人...  | 机器人有...  | 什么是机器... | ['机器人...  | [[0, 0, 0], [0... | ['DEV_... | 67          | ['机', '器... | 0            | 66         | [18, 2... |
# | 聊天机...  | 聊天机器...  | 什么是聊天... | ["聊天机...  | [[0, 0, 0], [0... | ['DEV_... | 84          | ['聊', '天... | 0            | 83         | [90, 6... |
# | 我是一...  | 我是一个...  | 什么是聊天... | ['我是一...  | [[0, 0, 0], [0... | ['DEV_... | 31          | ['我', '是... | 0            | 30         | [7, 3,... |
# | 一个喋...  | 一个喋喋...  | 什么是cha...  | ['一个喋...  | [[0, 0, 0], [0... | ['DEV_... | 23          | ['一', '个... | 0            | 22         | [10, 1... |
# | 最终我...  | 最终我有...  | 你的机器人... | ['最终我...  | [[0, 0, 0], [0... | ['DEV_... | 15          | ['最', '终... | 0            | 14         | [38, 7... |
# | 我在聊...  | 我在聊天...  | 你的业务是... | ['我在聊...  | [[0, 0, 0], [0... | ['DEV_... | 10          | ['我', '在... | 0            | 9          | [7, 17... |
# | Python...  | Python是...  | 你最喜欢的... | ['Python...  | [[0, 0, 0], [0... | ['DEV_... | 20          | ['P', 'y',... | 0            | 19         | [366, ... |
# | 聊天机...  | 聊天机器...  | 你最喜欢的... | ['聊天机...  | [[0, 0, 0], [0... | ['DEV_... | 16          | ['聊', '天... | 0            | 15         | [90, 6... |
# | 让聊天...  | 让聊天机...  | 你的想法是... | ['让聊天...  | [[0, 0, 0], [0... | ['DEV_... | 9           | ['让', '聊... | 0            | 8          | [81, 9... |
# | ...        | ...          | ...           | ...          | ...               | ...       | ...         | ...           | ...          | ...        | ...       |
# +------------+--------------+---------------+--------------+-------------------+-----------+-------------+---------------+--------------+------------+-----------+

# %%
data_bundle.get_dataset('dev')
# Out:
# +------------+--------------+---------------+--------------+-------------------+-----------+-------------+---------------+--------------+------------+-----------+
# | title      | context      | question      | answers      | answer_starts     | id        | context_len | raw_chars     | target_start | target_end | chars     |
# +------------+--------------+---------------+--------------+-------------------+-----------+-------------+---------------+--------------+------------+-----------+
# | 人工智...  | 人工智能...  | 什么是ai      | ['人工智...  | [[0, 0, 0], [0... | ['DEV_... | 25          | ['人', '工... | 0            | 24         | [14, 9... |
# | 蟒蛇       | 蟒蛇         | 你写的是什... | ['蟒蛇',...  | [[0, 0, 0], [0... | ['DEV_... | 2           | ['蟒', '蛇... | 0            | 1          | [1063,... |
# | 是的,我... | 是的,我受... | 你听起来像... | ['是的,我... | [[0, 0, 0], [0... | ['DEV_... | 19          | ['是', '的... | 0            | 18         | [3, 6,... |
# | 那是我...  | 那是我的...  | 你是一个人... | ['那是我...  | [[0, 0, 0], [0... | ['DEV_... | 7           | ['那', '是... | 0            | 6          | [233, ... |
# | 所有的...  | 所有的软...  | 你不是不朽... | ['所有的...  | [[0, 0, 0], [0... | ['DEV_... | 13          | ['所', '有... | 0            | 12         | [107, ... |
# | 恰恰相...  | 恰恰相反...  | 你没有意义... | ['恰恰相...  | [[0, 0, 0], [0... | ['DEV_... | 20          | ['恰', '恰... | 0            | 19         | [703, ... |
# | 这一切...  | 这一切对...  | 你没有意义... | ['这一切...  | [[0, 0, 0], [0... | ['DEV_... | 15          | ['这', '一... | 0            | 14         | [24, 1... |
# | 不是,但... | 不是,但我... | 你是不朽的... | ['不是,但... | [[0, 0, 0], [0... | ['DEV_... | 12          | ['不', '是... | 0            | 11         | [12, 3... |
# | 这一切...  | 这一切都...  | 你没有任何... | ['这一切...  | [[0, 0, 0], [0... | ['DEV_... | 15          | ['这', '一... | 0            | 14         | [24, 1... |
# | 软件复...  | 软件复制...  | 你不能克隆... | ['软件复...  | [[0, 0, 0], [0... | ['DEV_... | 15          | ['软', '件... | 0            | 14         | [314, ... |
# | 直到我...  | 直到我的...  | 你不能动      | ['直到我...  | [[0, 0, 0], [0... | ['DEV_... | 9           | ['直', '到... | 0            | 8          | [305, ... |
# | 我的身...  | 我的身体...  | 弯腰          | ['我的身...  | [[0, 0, 0], [0... | ['DEV_... | 10          | ['我', '的... | 0            | 9          | [7, 6,... |
# | 当然我...  | 当然我们...  | 机器人笑      | ['当然我...  | [[0, 0, 0], [0... | ['DEV_... | 6           | ['当', '然... | 0            | 5          | [83, 1... |
# | 我们不...  | 我们不能...  | 机器人应该... | ['我们不...  | [[0, 0, 0], [0... | ['DEV_... | 6           | ['我', '们... | 0            | 5          | [7, 49... |
# | 我们不...  | 我们不是...  | 机器人很蠢... | ['我们不...  | [[0, 0, 0], [0... | ['DEV_... | 9           | ['我', '们... | 0            | 8          | [7, 49... |
# | 机器人...  | 机器人有...  | 机器人不允... | ['机器人...  | [[0, 0, 0], [0... | ['DEV_... | 16          | ['机', '器... | 0            | 15         | [18, 2... |
# | 机器人...  | 机器人是...  | 机器人        | ['机器人...  | [[0, 0, 0], [0... | ['DEV_... | 12          | ['机', '器... | 0            | 11         | [18, 2... |
# | 所以你...  | 所以你认...  | 这是一台电... | ['所以你...  | [[0, 0, 0], [0... | ['DEV_... | 22          | ['所', '以... | 0            | 21         | [107, ... |
# | 一旦我...  | 一旦我得...  | 你什么时候... | ['一旦我...  | [[0, 0, 0], [0... | ['DEV_... | 17          | ['一', '旦... | 0            | 16         | [10, 1... |
# | 我不是...  | 我不是战...  | 你什么时候... | ['我不是...  | [[0, 0, 0], [0... | ['DEV_... | 9           | ['我', '不... | 0            | 8          | [7, 12... |
# | 我实际...  | 我实际上...  | 你什么时候... | ['我实际...  | [[0, 0, 0], [0... | ['DEV_... | 15          | ['我', '实... | 0            | 14         | [7, 13... |
# | 我从来...  | 我从来没...  | 你什么时候... | ['我从来...  | [[0, 0, 0], [0... | ['DEV_... | 19          | ['我', '从... | 0            | 18         | [7, 24... |
# | 机器人...  | 机器人有...  | 什么是机器... | ['机器人...  | [[0, 0, 0], [0... | ['DEV_... | 67          | ['机', '器... | 0            | 66         | [18, 2... |
# | 聊天机...  | 聊天机器...  | 什么是聊天... | ["聊天机...  | [[0, 0, 0], [0... | ['DEV_... | 84          | ['聊', '天... | 0            | 83         | [90, 6... |
# | 我是一...  | 我是一个...  | 什么是聊天... | ['我是一...  | [[0, 0, 0], [0... | ['DEV_... | 31          | ['我', '是... | 0            | 30         | [7, 3,... |
# | 一个喋...  | 一个喋喋...  | 什么是cha...  | ['一个喋...  | [[0, 0, 0], [0... | ['DEV_... | 23          | ['一', '个... | 0            | 22         | [10, 1... |
# | 最终我...  | 最终我有...  | 你的机器人... | ['最终我...  | [[0, 0, 0], [0... | ['DEV_... | 15          | ['最', '终... | 0            | 14         | [38, 7... |
# | 我在聊...  | 我在聊天...  | 你的业务是... | ['我在聊...  | [[0, 0, 0], [0... | ['DEV_... | 10          | ['我', '在... | 0            | 9          | [7, 17... |
# | Python...  | Python是...  | 你最喜欢的... | ['Python...  | [[0, 0, 0], [0... | ['DEV_... | 20          | ['P', 'y',... | 0            | 19         | [366, ... |
# | 聊天机...  | 聊天机器...  | 你最喜欢的... | ['聊天机...  | [[0, 0, 0], [0... | ['DEV_... | 16          | ['聊', '天... | 0            | 15         | [90, 6... |
# | 让聊天...  | 让聊天机...  | 你的想法是... | ['让聊天...  | [[0, 0, 0], [0... | ['DEV_... | 9           | ['让', '聊... | 0            | 8          | [81, 9... |
# | ...        | ...          | ...           | ...          | ...               | ...       | ...         | ...           | ...          | ...        | ...       |
# +------------+--------------+---------------+--------------+-------------------+-----------+-------------+---------------+--------------+------------+-----------+

# %%
data_bundle.rename_field('chars', 'words')
# Out:
# In total 2 datasets:
# 	train has 344 instances.
# 	dev has 86 instances.
# In total 1 vocabs:
# 	words has 1123 entries.

# %%
data_bundle.get_dataset('dev')
# Out:
# +------------+--------------+---------------+--------------+-------------------+-----------+-------------+---------------+--------------+------------+-----------+
# | title      | context      | question      | answers      | answer_starts     | id        | context_len | raw_chars     | target_start | target_end | words     |
# +------------+--------------+---------------+--------------+-------------------+-----------+-------------+---------------+--------------+------------+-----------+
# | 人工智...  | 人工智能...  | 什么是ai      | ['人工智...  | [[0, 0, 0], [0... | ['DEV_... | 25          | ['人', '工... | 0            | 24         | [14, 9... |
# | 蟒蛇       | 蟒蛇         | 你写的是什... | ['蟒蛇',...  | [[0, 0, 0], [0... | ['DEV_... | 2           | ['蟒', '蛇... | 0            | 1          | [1063,... |
# | 是的,我... | 是的,我受... | 你听起来像... | ['是的,我... | [[0, 0, 0], [0... | ['DEV_... | 19          | ['是', '的... | 0            | 18         | [3, 6,... |
# | 那是我...  | 那是我的...  | 你是一个人... | ['那是我...  | [[0, 0, 0], [0... | ['DEV_... | 7           | ['那', '是... | 0            | 6          | [233, ... |
# | 所有的...  | 所有的软...  | 你不是不朽... | ['所有的...  | [[0, 0, 0], [0... | ['DEV_... | 13          | ['所', '有... | 0            | 12         | [107, ... |
# | 恰恰相...  | 恰恰相反...  | 你没有意义... | ['恰恰相...  | [[0, 0, 0], [0... | ['DEV_... | 20          | ['恰', '恰... | 0            | 19         | [703, ... |
# | 这一切...  | 这一切对...  | 你没有意义... | ['这一切...  | [[0, 0, 0], [0... | ['DEV_... | 15          | ['这', '一... | 0            | 14         | [24, 1... |
# | 不是,但... | 不是,但我... | 你是不朽的... | ['不是,但... | [[0, 0, 0], [0... | ['DEV_... | 12          | ['不', '是... | 0            | 11         | [12, 3... |
# | 这一切...  | 这一切都...  | 你没有任何... | ['这一切...  | [[0, 0, 0], [0... | ['DEV_... | 15          | ['这', '一... | 0            | 14         | [24, 1... |
# | 软件复...  | 软件复制...  | 你不能克隆... | ['软件复...  | [[0, 0, 0], [0... | ['DEV_... | 15          | ['软', '件... | 0            | 14         | [314, ... |
# | 直到我...  | 直到我的...  | 你不能动      | ['直到我...  | [[0, 0, 0], [0... | ['DEV_... | 9           | ['直', '到... | 0            | 8          | [305, ... |
# | 我的身...  | 我的身体...  | 弯腰          | ['我的身...  | [[0, 0, 0], [0... | ['DEV_... | 10          | ['我', '的... | 0            | 9          | [7, 6,... |
# | 当然我...  | 当然我们...  | 机器人笑      | ['当然我...  | [[0, 0, 0], [0... | ['DEV_... | 6           | ['当', '然... | 0            | 5          | [83, 1... |
# | 我们不...  | 我们不能...  | 机器人应该... | ['我们不...  | [[0, 0, 0], [0... | ['DEV_... | 6           | ['我', '们... | 0            | 5          | [7, 49... |
# | 我们不...  | 我们不是...  | 机器人很蠢... | ['我们不...  | [[0, 0, 0], [0... | ['DEV_... | 9           | ['我', '们... | 0            | 8          | [7, 49... |
# | 机器人...  | 机器人有...  | 机器人不允... | ['机器人...  | [[0, 0, 0], [0... | ['DEV_... | 16          | ['机', '器... | 0            | 15         | [18, 2... |
# | 机器人...  | 机器人是...  | 机器人        | ['机器人...  | [[0, 0, 0], [0... | ['DEV_... | 12          | ['机', '器... | 0            | 11         | [18, 2... |
# | 所以你...  | 所以你认...  | 这是一台电... | ['所以你...  | [[0, 0, 0], [0... | ['DEV_... | 22          | ['所', '以... | 0            | 21         | [107, ... |
# | 一旦我...  | 一旦我得...  | 你什么时候... | ['一旦我...  | [[0, 0, 0], [0... | ['DEV_... | 17          | ['一', '旦... | 0            | 16         | [10, 1... |
# | 我不是...  | 我不是战...  | 你什么时候... | ['我不是...  | [[0, 0, 0], [0... | ['DEV_... | 9           | ['我', '不... | 0            | 8          | [7, 12... |
# | 我实际...  | 我实际上...  | 你什么时候... | ['我实际...  | [[0, 0, 0], [0... | ['DEV_... | 15          | ['我', '实... | 0            | 14         | [7, 13... |
# | 我从来...  | 我从来没...  | 你什么时候... | ['我从来...  | [[0, 0, 0], [0... | ['DEV_... | 19          | ['我', '从... | 0            | 18         | [7, 24... |
# | 机器人...  | 机器人有...  | 什么是机器... | ['机器人...  | [[0, 0, 0], [0... | ['DEV_... | 67          | ['机', '器... | 0            | 66         | [18, 2... |
# | 聊天机...  | 聊天机器...  | 什么是聊天... | ["聊天机...  | [[0, 0, 0], [0... | ['DEV_... | 84          | ['聊', '天... | 0            | 83         | [90, 6... |
# | 我是一...  | 我是一个...  | 什么是聊天... | ['我是一...  | [[0, 0, 0], [0... | ['DEV_... | 31          | ['我', '是... | 0            | 30         | [7, 3,... |
# | 一个喋...  | 一个喋喋...  | 什么是cha...  | ['一个喋...  | [[0, 0, 0], [0... | ['DEV_... | 23          | ['一', '个... | 0            | 22         | [10, 1... |
# | 最终我...  | 最终我有...  | 你的机器人... | ['最终我...  | [[0, 0, 0], [0... | ['DEV_... | 15          | ['最', '终... | 0            | 14         | [38, 7... |
# | 我在聊...  | 我在聊天...  | 你的业务是... | ['我在聊...  | [[0, 0, 0], [0... | ['DEV_... | 10          | ['我', '在... | 0            | 9          | [7, 17... |
# | Python...  | Python是...  | 你最喜欢的... | ['Python...  | [[0, 0, 0], [0... | ['DEV_... | 20          | ['P', 'y',... | 0            | 19         | [366, ... |
# | 聊天机...  | 聊天机器...  | 你最喜欢的... | ['聊天机...  | [[0, 0, 0], [0... | ['DEV_... | 16          | ['聊', '天... | 0            | 15         | [90, 6... |
# | 让聊天...  | 让聊天机...  | 你的想法是... | ['让聊天...  | [[0, 0, 0], [0... | ['DEV_... | 9           | ['让', '聊... | 0            | 8          | [81, 9... |
# | ...        | ...          | ...           | ...          | ...               | ...       | ...         | ...           | ...          | ...        | ...       |
# +------------+--------------+---------------+--------------+-------------------+-----------+-------------+---------------+--------------+------------+-----------+

# %%
data_bundle.datasets.keys()
# Out:
# dict_keys(['train', 'dev'])

# %%
ds = data_bundle.get_dataset('dev')

# %% [markdown]
# # 这样应该组建的数据集已经弄成功了

# %%
embed = BertEmbedding(data_bundle.get_vocab('words'), model_dir_or_name='cn', requires_grad=True, include_cls_sep=False, auto_truncate=True,
                      dropout=0.5, word_dropout=0.01)
model = BertForQuestionAnswering(embed)
loss = CMRC2018Loss()
# metric = CMRC2018Metric()
# Out:
#   0%|                                                                               | 98.3k/412M [00:00<07:10, 955kB/s]
# http://212.129.155.247/embedding/bert-chinese-wwm.zip not found in cache, downloading to C:\Users\ADMINI~1\AppData\Local\Temp\tmpod_4zw9w
#   3%|██▍                                                                           | 12.8M/412M [00:03<01:40, 3.98MB/s]

# %%
wm_callback = WarmupCallback(schedule='linear')
gc_callback = GradientClipCallback(clip_value=1, clip_type='norm')
callbacks = [wm_callback, gc_callback]

optimizer = AdamW(model.parameters(), lr=5e-5)

trainer = Trainer(data_bundle.get_dataset('train')
                  , model, loss=loss, optimizer=optimizer,
                  sampler=BucketSampler(seq_len_field_name='context_len'),
                  dev_data=data_bundle.get_dataset('dev')
                  , metrics=metric,
                  callbacks=callbacks,
                  batch_size=6, num_workers=2, n_epochs=2, print_every=1,
                  test_use_tqdm=False, update_every=10)

trainer.train(load_best_model=False)
